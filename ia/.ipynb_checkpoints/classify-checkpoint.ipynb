# %%
# !pip install dotenv
# Out:
# Requirement already satisfied: dotenv in /home/maximeadmin/anaconda3/envs/mon_env_ia/lib/python3.11/site-packages (0.9.9)
# Requirement already satisfied: python-dotenv in /home/maximeadmin/anaconda3/envs/mon_env_ia/lib/python3.11/site-packages (from dotenv) (1.0.1)

# %%
import google.generativeai as genai
from dotenv import load_dotenv
import os

# Charger les variables d'environnement depuis le fichier .env
load_dotenv()

api_key = os.environ.get("cle_gemini_api")
if not api_key:
    raise ValueError("La clé API n'est pas définie dans le fichier .env. Veuillez configurer la variable 'cle_api'.")

# Configurer le module avec la clé API
genai.configure(api_key=api_key)

# Exemple d'utilisation de l'API
for m in genai.list_models():
    print(m)
# Out:
# Model(name='models/chat-bison-001',
#       base_model_id='',
#       version='001',
#       display_name='PaLM 2 Chat (Legacy)',
#       description='A legacy text-only model optimized for chat conversations',
#       input_token_limit=4096,
#       output_token_limit=1024,
#       supported_generation_methods=['generateMessage', 'countMessageTokens'],
#       temperature=0.25,
#       max_temperature=None,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/text-bison-001',
#       base_model_id='',
#       version='001',
#       display_name='PaLM 2 (Legacy)',
#       description='A legacy model that understands text and generates text as an output',
#       input_token_limit=8196,
#       output_token_limit=1024,
#       supported_generation_methods=['generateText', 'countTextTokens', 'createTunedTextModel'],
#       temperature=0.7,
#       max_temperature=None,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/embedding-gecko-001',
#       base_model_id='',
#       version='001',
#       display_name='Embedding Gecko',
#       description='Obtain a distributed representation of a text.',
#       input_token_limit=1024,
#       output_token_limit=1,
#       supported_generation_methods=['embedText', 'countTextTokens'],
#       temperature=None,
#       max_temperature=None,
#       top_p=None,
#       top_k=None)
# Model(name='models/gemini-1.0-pro-vision-latest',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.0 Pro Vision',
#       description=('The original Gemini 1.0 Pro Vision model version which was optimized for '
#                    'image understanding. Gemini 1.0 Pro Vision was deprecated on July 12, 2024. '
#                    'Move to a newer Gemini version.'),
#       input_token_limit=12288,
#       output_token_limit=4096,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=0.4,
#       max_temperature=None,
#       top_p=1.0,
#       top_k=32)
# Model(name='models/gemini-pro-vision',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.0 Pro Vision',
#       description=('The original Gemini 1.0 Pro Vision model version which was optimized for '
#                    'image understanding. Gemini 1.0 Pro Vision was deprecated on July 12, 2024. '
#                    'Move to a newer Gemini version.'),
#       input_token_limit=12288,
#       output_token_limit=4096,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=0.4,
#       max_temperature=None,
#       top_p=1.0,
#       top_k=32)
# Model(name='models/gemini-1.5-pro-latest',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.5 Pro Latest',
#       description=('Alias that points to the most recent production (non-experimental) release '
#                    'of Gemini 1.5 Pro, our mid-size multimodal model that supports up to 2 '
#                    'million tokens.'),
#       input_token_limit=2000000,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-1.5-pro-001',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.5 Pro 001',
#       description=('Stable version of Gemini 1.5 Pro, our mid-size multimodal model that '
#                    'supports up to 2 million tokens, released in May of 2024.'),
#       input_token_limit=2000000,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens', 'createCachedContent'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=64)
# Model(name='models/gemini-1.5-pro-002',
#       base_model_id='',
#       version='002',
#       display_name='Gemini 1.5 Pro 002',
#       description=('Stable version of Gemini 1.5 Pro, our mid-size multimodal model that '
#                    'supports up to 2 million tokens, released in September of 2024.'),
#       input_token_limit=2000000,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens', 'createCachedContent'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-1.5-pro',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.5 Pro',
#       description=('Stable version of Gemini 1.5 Pro, our mid-size multimodal model that '
#                    'supports up to 2 million tokens, released in May of 2024.'),
#       input_token_limit=2000000,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-1.5-flash-latest',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.5 Flash Latest',
#       description=('Alias that points to the most recent production (non-experimental) release '
#                    'of Gemini 1.5 Flash, our fast and versatile multimodal model for scaling '
#                    'across diverse tasks.'),
#       input_token_limit=1000000,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-1.5-flash-001',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.5 Flash 001',
#       description=('Stable version of Gemini 1.5 Flash, our fast and versatile multimodal model '
#                    'for scaling across diverse tasks, released in May of 2024.'),
#       input_token_limit=1000000,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens', 'createCachedContent'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=64)
# Model(name='models/gemini-1.5-flash-001-tuning',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.5 Flash 001 Tuning',
#       description=('Version of Gemini 1.5 Flash that supports tuning, our fast and versatile '
#                    'multimodal model for scaling across diverse tasks, released in May of 2024.'),
#       input_token_limit=16384,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens', 'createTunedModel'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=64)
# Model(name='models/gemini-1.5-flash',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.5 Flash',
#       description=('Alias that points to the most recent stable version of Gemini 1.5 Flash, our '
#                    'fast and versatile multimodal model for scaling across diverse tasks.'),
#       input_token_limit=1000000,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-1.5-flash-002',
#       base_model_id='',
#       version='002',
#       display_name='Gemini 1.5 Flash 002',
#       description=('Stable version of Gemini 1.5 Flash, our fast and versatile multimodal model '
#                    'for scaling across diverse tasks, released in September of 2024.'),
#       input_token_limit=1000000,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens', 'createCachedContent'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-1.5-flash-8b',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.5 Flash-8B',
#       description=('Stable version of Gemini 1.5 Flash-8B, our smallest and most cost effective '
#                    'Flash model, released in October of 2024.'),
#       input_token_limit=1000000,
#       output_token_limit=8192,
#       supported_generation_methods=['createCachedContent', 'generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-1.5-flash-8b-001',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.5 Flash-8B 001',
#       description=('Stable version of Gemini 1.5 Flash-8B, our smallest and most cost effective '
#                    'Flash model, released in October of 2024.'),
#       input_token_limit=1000000,
#       output_token_limit=8192,
#       supported_generation_methods=['createCachedContent', 'generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-1.5-flash-8b-latest',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.5 Flash-8B Latest',
#       description=('Alias that points to the most recent production (non-experimental) release '
#                    'of Gemini 1.5 Flash-8B, our smallest and most cost effective Flash model, '
#                    'released in October of 2024.'),
#       input_token_limit=1000000,
#       output_token_limit=8192,
#       supported_generation_methods=['createCachedContent', 'generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-1.5-flash-8b-exp-0827',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.5 Flash 8B Experimental 0827',
#       description=('Experimental release (August 27th, 2024) of Gemini 1.5 Flash-8B, our '
#                    'smallest and most cost effective Flash model. Replaced by '
#                    'Gemini-1.5-flash-8b-001 (stable).'),
#       input_token_limit=1000000,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-1.5-flash-8b-exp-0924',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.5 Flash 8B Experimental 0924',
#       description=('Experimental release (September 24th, 2024) of Gemini 1.5 Flash-8B, our '
#                    'smallest and most cost effective Flash model. Replaced by '
#                    'Gemini-1.5-flash-8b-001 (stable).'),
#       input_token_limit=1000000,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-2.0-flash-exp',
#       base_model_id='',
#       version='2.0',
#       display_name='Gemini 2.0 Flash Experimental',
#       description='Gemini 2.0 Flash Experimental',
#       input_token_limit=1048576,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens', 'bidiGenerateContent'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-2.0-flash',
#       base_model_id='',
#       version='2.0',
#       display_name='Gemini 2.0 Flash',
#       description='Gemini 2.0 Flash',
#       input_token_limit=1048576,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-2.0-flash-001',
#       base_model_id='',
#       version='2.0',
#       display_name='Gemini 2.0 Flash 001',
#       description=('Stable version of Gemini 2.0 Flash, our fast and versatile multimodal model '
#                    'for scaling across diverse tasks, released in January of 2025.'),
#       input_token_limit=1048576,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-2.0-flash-exp-image-generation',
#       base_model_id='',
#       version='2.0',
#       display_name='Gemini 2.0 Flash (Image Generation) Experimental',
#       description='Gemini 2.0 Flash (Image Generation) Experimental',
#       input_token_limit=1048576,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens', 'bidiGenerateContent'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-2.0-flash-lite-001',
#       base_model_id='',
#       version='2.0',
#       display_name='Gemini 2.0 Flash-Lite 001',
#       description='Stable version of Gemini 2.0 Flash Lite',
#       input_token_limit=1048576,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-2.0-flash-lite',
#       base_model_id='',
#       version='2.0',
#       display_name='Gemini 2.0 Flash-Lite',
#       description='Gemini 2.0 Flash-Lite',
#       input_token_limit=1048576,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-2.0-flash-lite-preview-02-05',
#       base_model_id='',
#       version='preview-02-05',
#       display_name='Gemini 2.0 Flash-Lite Preview 02-05',
#       description='Preview release (February 5th, 2025) of Gemini 2.0 Flash Lite',
#       input_token_limit=1048576,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-2.0-flash-lite-preview',
#       base_model_id='',
#       version='preview-02-05',
#       display_name='Gemini 2.0 Flash-Lite Preview',
#       description='Preview release (February 5th, 2025) of Gemini 2.0 Flash Lite',
#       input_token_limit=1048576,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-2.0-pro-exp',
#       base_model_id='',
#       version='2.0',
#       display_name='Gemini 2.0 Pro Experimental',
#       description='Experimental release (February 5th, 2025) of Gemini 2.0 Pro',
#       input_token_limit=2097152,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=64)
# Model(name='models/gemini-2.0-pro-exp-02-05',
#       base_model_id='',
#       version='2.0',
#       display_name='Gemini 2.0 Pro Experimental 02-05',
#       description='Experimental release (February 5th, 2025) of Gemini 2.0 Pro',
#       input_token_limit=2097152,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=64)
# Model(name='models/gemini-exp-1206',
#       base_model_id='',
#       version='2.0',
#       display_name='Gemini Experimental 1206',
#       description='Experimental release (February 5th, 2025) of Gemini 2.0 Pro',
#       input_token_limit=2097152,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=64)
# Model(name='models/gemini-2.0-flash-thinking-exp-01-21',
#       base_model_id='',
#       version='2.0-exp-01-21',
#       display_name='Gemini 2.0 Flash Thinking Experimental 01-21',
#       description='Experimental release (January 21st, 2025) of Gemini 2.0 Flash Thinking',
#       input_token_limit=1048576,
#       output_token_limit=65536,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=0.7,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=64)
# Model(name='models/gemini-2.0-flash-thinking-exp',
#       base_model_id='',
#       version='2.0-exp-01-21',
#       display_name='Gemini 2.0 Flash Thinking Experimental 01-21',
#       description='Experimental release (January 21st, 2025) of Gemini 2.0 Flash Thinking',
#       input_token_limit=1048576,
#       output_token_limit=65536,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=0.7,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=64)
# Model(name='models/gemini-2.0-flash-thinking-exp-1219',
#       base_model_id='',
#       version='2.0',
#       display_name='Gemini 2.0 Flash Thinking Experimental',
#       description='Gemini 2.0 Flash Thinking Experimental',
#       input_token_limit=1048576,
#       output_token_limit=65536,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=0.7,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=64)
# Model(name='models/learnlm-1.5-pro-experimental',
#       base_model_id='',
#       version='001',
#       display_name='LearnLM 1.5 Pro Experimental',
#       description=('Alias that points to the most recent stable version of Gemini 1.5 Pro, our '
#                    'mid-size multimodal model that supports up to 2 million tokens.'),
#       input_token_limit=32767,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=64)
# Model(name='models/gemma-3-27b-it',
#       base_model_id='',
#       version='001',
#       display_name='Gemma 3 27B',
#       description='',
#       input_token_limit=131072,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=None,
#       top_p=0.95,
#       top_k=64)
# Model(name='models/embedding-001',
#       base_model_id='',
#       version='001',
#       display_name='Embedding 001',
#       description='Obtain a distributed representation of a text.',
#       input_token_limit=2048,
#       output_token_limit=1,
#       supported_generation_methods=['embedContent'],
#       temperature=None,
#       max_temperature=None,
#       top_p=None,
#       top_k=None)
# Model(name='models/text-embedding-004',
#       base_model_id='',
#       version='004',
#       display_name='Text Embedding 004',
#       description='Obtain a distributed representation of a text.',
#       input_token_limit=2048,
#       output_token_limit=1,
#       supported_generation_methods=['embedContent'],
#       temperature=None,
#       max_temperature=None,
#       top_p=None,
#       top_k=None)
# Model(name='models/gemini-embedding-exp-03-07',
#       base_model_id='',
#       version='exp-03-07',
#       display_name='Gemini Embedding Experimental 03-07',
#       description='Obtain a distributed representation of a text.',
#       input_token_limit=8192,
#       output_token_limit=1,
#       supported_generation_methods=['embedContent'],
#       temperature=None,
#       max_temperature=None,
#       top_p=None,
#       top_k=None)
# Model(name='models/gemini-embedding-exp',
#       base_model_id='',
#       version='exp-03-07',
#       display_name='Gemini Embedding Experimental',
#       description='Obtain a distributed representation of a text.',
#       input_token_limit=8192,
#       output_token_limit=1,
#       supported_generation_methods=['embedContent'],
#       temperature=None,
#       max_temperature=None,
#       top_p=None,
#       top_k=None)
# Model(name='models/aqa',
#       base_model_id='',
#       version='001',
#       display_name='Model that performs Attributed Question Answering.',
#       description=('Model trained to return answers to questions that are grounded in provided '
#                    'sources, along with estimating answerable probability.'),
#       input_token_limit=7168,
#       output_token_limit=1024,
#       supported_generation_methods=['generateAnswer'],
#       temperature=0.2,
#       max_temperature=None,
#       top_p=1.0,
#       top_k=40)
# Model(name='models/imagen-3.0-generate-002',
#       base_model_id='',
#       version='002',
#       display_name='Imagen 3.0 002 model',
#       description='Vertex served Imagen 3.0 002 model',
#       input_token_limit=480,
#       output_token_limit=8192,
#       supported_generation_methods=['predict'],
#       temperature=None,
#       max_temperature=None,
#       top_p=None,
#       top_k=None)

# %%
import google.generativeai as genai
from dotenv import load_dotenv
import os
import json
import glob
import re

# Charger les variables d'environnement depuis le fichier .env
load_dotenv()

api_key = os.environ.get("cle_gemini_api")
if not api_key:
    raise ValueError("La clé API n'est pas définie dans le fichier .env. Veuillez configurer la variable 'cle_api'.")

# Configurer le module avec la clé API
genai.configure(api_key=api_key)

# Sélectionner le modèle.  gemini-1.5-pro est un bon choix
model = genai.GenerativeModel('gemini-1.5-pro')


def load_chapters(json_file):
    """Charge les chapitres et sous-chapitres depuis un fichier JSON."""
    with open(json_file, 'r', encoding='utf-8') as f:
        data = json.load(f)
    return data


def extract_text_from_tex(tex_file):
    """Extrait le texte d'un fichier .tex en supprimant les commandes LaTeX de base."""
    try:
        with open(tex_file, 'r', encoding='utf-8') as f:
            text = f.read()

        # Supprimer les commentaires
        text = re.sub(r"%.*", "", text)

        # Supprimer les commandes LaTeX (peut être amélioré pour plus de robustesse)
        text = re.sub(r"\\[a-zA-Z]+\{.*?\}", "", text)  # Supprimer les commandes avec arguments entre accolades
        text = re.sub(r"\\[a-zA-Z]+", "", text) # Supprimer les commandes sans arguments

        # Supprimer les environnements (begin...end)
        text = re.sub(r"\\begin\{.*?\}.*?\\end\{.*?\}.*", "", text, flags=re.DOTALL)

        # Supprimer les balises mathématiques inline et hors ligne
        text = re.sub(r"\$.*?\$", "", text)
        text = re.sub(r"\$\$[\s\S]*?\$\$", "", text)

        # Supprimer les figures
        text = re.sub(r"\\begin\{figure\}.*?\\end\{figure\}", "", text, flags=re.DOTALL)


        # Nettoyer les espaces multiples et les sauts de ligne
        text = re.sub(r"\s+", " ", text).strip()
        return text
    except Exception as e:
        print(f"Erreur lors de la lecture/extraction du fichier {tex_file}: {e}")
        return ""


import time

def classify_tex_file(text_content, chapters):
    """
    Classifie le contenu d'un fichier .tex et retourne le chapitre et le sous-chapitre les plus pertinents.
    """
    prompt = f"""
    Vous êtes un classificateur de documents. Votre tâche est de déterminer le chapitre et le sous-chapitre les plus pertinents pour un texte donné.
    Vous devez absolument respecter le format de sortie.

    Voici une liste de chapitres et sous-chapitres possibles:
    {json.dumps(chapters, indent=2, ensure_ascii=False)}

    Texte à classifier:
    {text_content}

    Fournissez votre réponse au format JSON suivant :
    {{
        "chapitre": "Nom du chapitre",
        "sousChapitre": "Nom du sous-chapitre"
    }}

    Ne répondez qu'avec le JSON.
    """

    max_retries = 5
    delay = 1  # secondes

    for attempt in range(max_retries):
        try:
            response = model.generate_content(prompt)
            # print(response.text)
            json_string = response.text.strip()

            # Supprimer le préfixe "json" s'il est présent
            if json_string.startswith("json"):
                json_string = json_string[4:].strip()

            #Correction si besoin d'erreurs dans la string JSON
            json_string = json_string.replace("`","")

            try:
                classification = json.loads(json_string)
                return classification["chapitre"], classification["sousChapitre"]
            except json.JSONDecodeError as e:
                print(f"Erreur de décodage JSON: {e}")
                print(f"String JSON recue: {json_string}")
                return None, None  # Gérer l'erreur de décodage JSON

        except Exception as e:
            print(f"Erreur lors de l'appel à l'API Gemini (tentative {attempt + 1}/{max_retries}): {e}")
            if "429" in str(e):  # Vérifie si l'erreur est liée au quota
                print(f"Quota dépassé. Attente de {delay} secondes...")
                time.sleep(delay)
                delay *= 2  # Augmente le délai de façon exponentielle
            else:
                # Autre erreur, ne pas réessayer
                return None, None

    print(f"Échec après {max_retries} tentatives.")
    return None, None  # Retourne None si toutes les tentatives échouent


def insert_chapter_info(tex_file, chapitre, sous_chapitre):
    """Insère les commandes \\chapitre et \\sousChapitre au début du fichier .tex."""
    try:
        with open(tex_file, 'r+', encoding='utf-8') as f:
            content = f.read()
            f.seek(0, 0)  # Retour au début du fichier
            f.write(f"\\chapitre{{{chapitre}}}\n")
            f.write(f"\\sousChapitre{{{sous_chapitre}}}\n")
            f.write(content)
    except Exception as e:
        print(f"Erreur lors de l'écriture dans le fichier {tex_file}: {e}")


def main():
    """Fonction principale pour classifier et insérer les informations dans les fichiers .tex."""
    chapters = load_chapters("../metadata/exo7/chapitres_complet.json")
    tex_files = glob.glob("../src/latex/amscc/*.tex")

    for tex_file in tex_files:
        print(f"Traitement du fichier: {tex_file}")
        text_content = extract_text_from_tex(tex_file)

        if text_content:
            chapitre, sous_chapitre = classify_tex_file(text_content, chapters)

            if chapitre and sous_chapitre:
                print(f"  Chapitre: {chapitre}")
                print(f"  Sous-chapitre: {sous_chapitre}")
                insert_chapter_info(tex_file, chapitre, sous_chapitre)
                print(f"  Informations insérées dans {tex_file}")
            else:
                print(f"  Impossible de classifier {tex_file}")
        else:
            print(f"  Impossible d'extraire le texte de {tex_file}")


if __name__ == "__main__":
    main()
# Out:
# Traitement du fichier: ../src/latex/amscc/YBwt.tex
# Erreur de décodage JSON: Expecting value: line 1 column 1 (char 0)
# String JSON recue: json
# {
#   "chapitre": "Probabilité discrète",
#   "sousChapitre": "Lois de distributions"
# }
#
#   Impossible de classifier ../src/latex/amscc/YBwt.tex
# Traitement du fichier: ../src/latex/amscc/trhY.tex
# Erreur de décodage JSON: Expecting value: line 1 column 1 (char 0)
# String JSON recue: json
# {
#   "chapitre": "Statistique",
#   "sousChapitre": "Tests d'hypothèses, intervalle de confiance"
# }
#
#   Impossible de classifier ../src/latex/amscc/trhY.tex
# Traitement du fichier: ../src/latex/amscc/aWAS.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/aWAS.tex
# Traitement du fichier: ../src/latex/amscc/DEZs.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/DEZs.tex
# Traitement du fichier: ../src/latex/amscc/5cbY.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/5cbY.tex
# Traitement du fichier: ../src/latex/amscc/ouYw.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/ouYw.tex
# Traitement du fichier: ../src/latex/amscc/6NIK.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/6NIK.tex
# Traitement du fichier: ../src/latex/amscc/PPhD.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/PPhD.tex
# Traitement du fichier: ../src/latex/amscc/0oHk.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/0oHk.tex
# Traitement du fichier: ../src/latex/amscc/hWFx.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/hWFx.tex
# Traitement du fichier: ../src/latex/amscc/Uijb.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/Uijb.tex
# Traitement du fichier: ../src/latex/amscc/7aqI.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/7aqI.tex
# Traitement du fichier: ../src/latex/amscc/cEVS.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/cEVS.tex
# Traitement du fichier: ../src/latex/amscc/tNNT.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/tNNT.tex
# Traitement du fichier: ../src/latex/amscc/gsn9.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/gsn9.tex
# Traitement du fichier: ../src/latex/amscc/yp7e.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/yp7e.tex
# Traitement du fichier: ../src/latex/amscc/cLt6.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/cLt6.tex
# Traitement du fichier: ../src/latex/amscc/qGRj.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/qGRj.tex
# Traitement du fichier: ../src/latex/amscc/Y6X6.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/Y6X6.tex
# Traitement du fichier: ../src/latex/amscc/Stxj.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/Stxj.tex
# Traitement du fichier: ../src/latex/amscc/AKnT.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/AKnT.tex
# Traitement du fichier: ../src/latex/amscc/BGJz.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/BGJz.tex
# Traitement du fichier: ../src/latex/amscc/femq.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/femq.tex
# Traitement du fichier: ../src/latex/amscc/TwOd.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/TwOd.tex
# Traitement du fichier: ../src/latex/amscc/kOVx.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/kOVx.tex
# Traitement du fichier: ../src/latex/amscc/tPCs.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/tPCs.tex
# Traitement du fichier: ../src/latex/amscc/xTQK.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/xTQK.tex
# Traitement du fichier: ../src/latex/amscc/AS6p.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/AS6p.tex
# Traitement du fichier: ../src/latex/amscc/pfS1.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/pfS1.tex
# Traitement du fichier: ../src/latex/amscc/HojS.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/HojS.tex
# Traitement du fichier: ../src/latex/amscc/KfgI.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/KfgI.tex
# Traitement du fichier: ../src/latex/amscc/SfKE.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/SfKE.tex
# Traitement du fichier: ../src/latex/amscc/IC6C.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/IC6C.tex
# Traitement du fichier: ../src/latex/amscc/BA22.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/BA22.tex
# Traitement du fichier: ../src/latex/amscc/uSXE.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/uSXE.tex
# Traitement du fichier: ../src/latex/amscc/MZkM.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/MZkM.tex
# Traitement du fichier: ../src/latex/amscc/CLjr.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/CLjr.tex
# Traitement du fichier: ../src/latex/amscc/o5At.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/o5At.tex
# Traitement du fichier: ../src/latex/amscc/dC7P.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/dC7P.tex
# Traitement du fichier: ../src/latex/amscc/hqXo.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/hqXo.tex
# Traitement du fichier: ../src/latex/amscc/H0fC.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/H0fC.tex
# Traitement du fichier: ../src/latex/amscc/Xvzc.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/Xvzc.tex
# Traitement du fichier: ../src/latex/amscc/NCVL.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/NCVL.tex
# Traitement du fichier: ../src/latex/amscc/oXIK.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/oXIK.tex
# Traitement du fichier: ../src/latex/amscc/5Df5.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/5Df5.tex
# Traitement du fichier: ../src/latex/amscc/AGDn.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/AGDn.tex
# Traitement du fichier: ../src/latex/amscc/r0au.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/r0au.tex
# Traitement du fichier: ../src/latex/amscc/ReNe.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/ReNe.tex
# Traitement du fichier: ../src/latex/amscc/rf0B.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/rf0B.tex
# Traitement du fichier: ../src/latex/amscc/Syo2.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/Syo2.tex
# Traitement du fichier: ../src/latex/amscc/bXCC.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/bXCC.tex
# Traitement du fichier: ../src/latex/amscc/cpBJ.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/cpBJ.tex
# Traitement du fichier: ../src/latex/amscc/ZVIr.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/ZVIr.tex
# Traitement du fichier: ../src/latex/amscc/ycEr.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/ycEr.tex
# Traitement du fichier: ../src/latex/amscc/dsIx.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/dsIx.tex
# Traitement du fichier: ../src/latex/amscc/MWOk.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/MWOk.tex
# Traitement du fichier: ../src/latex/amscc/Ueb3.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/Ueb3.tex
# Traitement du fichier: ../src/latex/amscc/8SbE.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/8SbE.tex
# Traitement du fichier: ../src/latex/amscc/Bs5w.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/Bs5w.tex
# Traitement du fichier: ../src/latex/amscc/M7Z5.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/M7Z5.tex
# Traitement du fichier: ../src/latex/amscc/5hoU.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/5hoU.tex
# Traitement du fichier: ../src/latex/amscc/WCGV.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/WCGV.tex
# Traitement du fichier: ../src/latex/amscc/ZT9T.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/ZT9T.tex
# Traitement du fichier: ../src/latex/amscc/JPjn.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/JPjn.tex
# Traitement du fichier: ../src/latex/amscc/Sqjo.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/Sqjo.tex
# Traitement du fichier: ../src/latex/amscc/PUWY.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/PUWY.tex
# Traitement du fichier: ../src/latex/amscc/fGoC.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/fGoC.tex
# Traitement du fichier: ../src/latex/amscc/5FLs.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/5FLs.tex
# Traitement du fichier: ../src/latex/amscc/0uqI.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/0uqI.tex
# Traitement du fichier: ../src/latex/amscc/653s.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/653s.tex
# Traitement du fichier: ../src/latex/amscc/5gPB.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/5gPB.tex
# Traitement du fichier: ../src/latex/amscc/tSoF.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/tSoF.tex
# Traitement du fichier: ../src/latex/amscc/vt62.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/vt62.tex
# Traitement du fichier: ../src/latex/amscc/qNxE.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/qNxE.tex
# Traitement du fichier: ../src/latex/amscc/rhUy.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/rhUy.tex
# Traitement du fichier: ../src/latex/amscc/9MyW.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/9MyW.tex
# Traitement du fichier: ../src/latex/amscc/Cefu.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/Cefu.tex
# Traitement du fichier: ../src/latex/amscc/MPPL.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/MPPL.tex
# Traitement du fichier: ../src/latex/amscc/f4ze.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/f4ze.tex
# Traitement du fichier: ../src/latex/amscc/tPHB.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/tPHB.tex
# Traitement du fichier: ../src/latex/amscc/DkOf.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/DkOf.tex
# Traitement du fichier: ../src/latex/amscc/Fe1h.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/Fe1h.tex
# Traitement du fichier: ../src/latex/amscc/Z8Dq.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/Z8Dq.tex
# Traitement du fichier: ../src/latex/amscc/mVsg.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/mVsg.tex
# Traitement du fichier: ../src/latex/amscc/ebva.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/ebva.tex
# Traitement du fichier: ../src/latex/amscc/O5Wz.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/O5Wz.tex
# Traitement du fichier: ../src/latex/amscc/wlig.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/wlig.tex
# Traitement du fichier: ../src/latex/amscc/z0hC.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/z0hC.tex
# Traitement du fichier: ../src/latex/amscc/kzan.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/kzan.tex
# Traitement du fichier: ../src/latex/amscc/Z6wd.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/Z6wd.tex
# Traitement du fichier: ../src/latex/amscc/4R9m.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/4R9m.tex
# Traitement du fichier: ../src/latex/amscc/Hhtu.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/Hhtu.tex
# Traitement du fichier: ../src/latex/amscc/buE8.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/buE8.tex
# Traitement du fichier: ../src/latex/amscc/yTDM.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/yTDM.tex
# Traitement du fichier: ../src/latex/amscc/HvSs.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/HvSs.tex
# Traitement du fichier: ../src/latex/amscc/nSDY.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/nSDY.tex
# Traitement du fichier: ../src/latex/amscc/C5Fq.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/C5Fq.tex
# Traitement du fichier: ../src/latex/amscc/TgsV.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/TgsV.tex
# Traitement du fichier: ../src/latex/amscc/nSSt.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/nSSt.tex
# Traitement du fichier: ../src/latex/amscc/XtkF.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/XtkF.tex
# Traitement du fichier: ../src/latex/amscc/nsgN.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/nsgN.tex
# Traitement du fichier: ../src/latex/amscc/YIXX.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/YIXX.tex
# Traitement du fichier: ../src/latex/amscc/jj3V.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/jj3V.tex
# Traitement du fichier: ../src/latex/amscc/UDat.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/UDat.tex
# Traitement du fichier: ../src/latex/amscc/4Idt.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/4Idt.tex
# Traitement du fichier: ../src/latex/amscc/yNs9.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/yNs9.tex
# Traitement du fichier: ../src/latex/amscc/UbhS.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/UbhS.tex
# Traitement du fichier: ../src/latex/amscc/EXyV.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/EXyV.tex
# Traitement du fichier: ../src/latex/amscc/9oDf.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/9oDf.tex
# Traitement du fichier: ../src/latex/amscc/6er6.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/6er6.tex
# Traitement du fichier: ../src/latex/amscc/wjwa.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/wjwa.tex
# Traitement du fichier: ../src/latex/amscc/tSVB.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/tSVB.tex
# Traitement du fichier: ../src/latex/amscc/sPl1.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/sPl1.tex
# Traitement du fichier: ../src/latex/amscc/A2Gl.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/A2Gl.tex
# Traitement du fichier: ../src/latex/amscc/wBKf.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/wBKf.tex
# Traitement du fichier: ../src/latex/amscc/rsjs.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/rsjs.tex
# Traitement du fichier: ../src/latex/amscc/6TSn.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/6TSn.tex
# Traitement du fichier: ../src/latex/amscc/lX53.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/lX53.tex
# Traitement du fichier: ../src/latex/amscc/3kdw.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/3kdw.tex
# Traitement du fichier: ../src/latex/amscc/lH75.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/lH75.tex
# Traitement du fichier: ../src/latex/amscc/zhwJ.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/zhwJ.tex
# Traitement du fichier: ../src/latex/amscc/hLkm.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/hLkm.tex
# Traitement du fichier: ../src/latex/amscc/tLxt.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/tLxt.tex
# Traitement du fichier: ../src/latex/amscc/j4xc.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/j4xc.tex
# Traitement du fichier: ../src/latex/amscc/GmNP.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/GmNP.tex
# Traitement du fichier: ../src/latex/amscc/nxfH.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/nxfH.tex
# Traitement du fichier: ../src/latex/amscc/urin.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/urin.tex
# Traitement du fichier: ../src/latex/amscc/XoM4.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/XoM4.tex
# Traitement du fichier: ../src/latex/amscc/r5Yy.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/r5Yy.tex
# Traitement du fichier: ../src/latex/amscc/JDv8.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/JDv8.tex
# Traitement du fichier: ../src/latex/amscc/Y8t7.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/Y8t7.tex
# Traitement du fichier: ../src/latex/amscc/KSes.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/KSes.tex
# Traitement du fichier: ../src/latex/amscc/d4sm.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/d4sm.tex
# Traitement du fichier: ../src/latex/amscc/LBLK.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/LBLK.tex
# Traitement du fichier: ../src/latex/amscc/s7LB.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/s7LB.tex
# Traitement du fichier: ../src/latex/amscc/lqVs.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/lqVs.tex
# Traitement du fichier: ../src/latex/amscc/aoB6.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/aoB6.tex
# Traitement du fichier: ../src/latex/amscc/uVBn.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/uVBn.tex
# Traitement du fichier: ../src/latex/amscc/XGrp.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/XGrp.tex
# Traitement du fichier: ../src/latex/amscc/lz1J.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/lz1J.tex
# Traitement du fichier: ../src/latex/amscc/XKwm.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/XKwm.tex
# Traitement du fichier: ../src/latex/amscc/R0SQ.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/R0SQ.tex
# Traitement du fichier: ../src/latex/amscc/JHnB.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/JHnB.tex
# Traitement du fichier: ../src/latex/amscc/Jfwq.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/Jfwq.tex
# Traitement du fichier: ../src/latex/amscc/ZyzY.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/ZyzY.tex
# Traitement du fichier: ../src/latex/amscc/xs4r.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/xs4r.tex
# Traitement du fichier: ../src/latex/amscc/g6Rl.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/g6Rl.tex
# Traitement du fichier: ../src/latex/amscc/dRbq.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/dRbq.tex
# Traitement du fichier: ../src/latex/amscc/gAMY.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/gAMY.tex
# Traitement du fichier: ../src/latex/amscc/YUNF.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/YUNF.tex
# Traitement du fichier: ../src/latex/amscc/S3Kp.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/S3Kp.tex
# Traitement du fichier: ../src/latex/amscc/GGzj.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/GGzj.tex
# Traitement du fichier: ../src/latex/amscc/iboj.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/iboj.tex
# Traitement du fichier: ../src/latex/amscc/krLE.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/krLE.tex
# Traitement du fichier: ../src/latex/amscc/XQqR.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/XQqR.tex
# Traitement du fichier: ../src/latex/amscc/5sHJ.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/5sHJ.tex
# Traitement du fichier: ../src/latex/amscc/pWdA.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/pWdA.tex
# Traitement du fichier: ../src/latex/amscc/zmLP.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/zmLP.tex
# Traitement du fichier: ../src/latex/amscc/tRMg.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/tRMg.tex
# Traitement du fichier: ../src/latex/amscc/PAzn.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/PAzn.tex
# Traitement du fichier: ../src/latex/amscc/9UsO.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/9UsO.tex
# Traitement du fichier: ../src/latex/amscc/iwFE.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/iwFE.tex
# Traitement du fichier: ../src/latex/amscc/1fDE.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/1fDE.tex
# Traitement du fichier: ../src/latex/amscc/r3ax.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/r3ax.tex
# Traitement du fichier: ../src/latex/amscc/s2lI.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/s2lI.tex
# Traitement du fichier: ../src/latex/amscc/rVaz.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/rVaz.tex
# Traitement du fichier: ../src/latex/amscc/ZIua.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/ZIua.tex
# Traitement du fichier: ../src/latex/amscc/Hubl.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/Hubl.tex
# Traitement du fichier: ../src/latex/amscc/aRzj.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/aRzj.tex
# Traitement du fichier: ../src/latex/amscc/na3z.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/na3z.tex
# Traitement du fichier: ../src/latex/amscc/xCO3.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/xCO3.tex
# Traitement du fichier: ../src/latex/amscc/3zDK.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/3zDK.tex
# Traitement du fichier: ../src/latex/amscc/ItUH.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/ItUH.tex
# Traitement du fichier: ../src/latex/amscc/gl15.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/gl15.tex
# Traitement du fichier: ../src/latex/amscc/nhpq.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/nhpq.tex
# Traitement du fichier: ../src/latex/amscc/FaOL.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/FaOL.tex
# Traitement du fichier: ../src/latex/amscc/Bf5M.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/Bf5M.tex
# Traitement du fichier: ../src/latex/amscc/rB1j.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/rB1j.tex
# Traitement du fichier: ../src/latex/amscc/xTI2.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/xTI2.tex
# Traitement du fichier: ../src/latex/amscc/RsEy.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/RsEy.tex
# Traitement du fichier: ../src/latex/amscc/Y8mj.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/Y8mj.tex
# Traitement du fichier: ../src/latex/amscc/kzF4.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/kzF4.tex
# Traitement du fichier: ../src/latex/amscc/XlVt.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/XlVt.tex
# Traitement du fichier: ../src/latex/amscc/4iSJ.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/4iSJ.tex
# Traitement du fichier: ../src/latex/amscc/LHbK.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/LHbK.tex
# Traitement du fichier: ../src/latex/amscc/ingl.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/ingl.tex
# Traitement du fichier: ../src/latex/amscc/0U2g.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/0U2g.tex
# Traitement du fichier: ../src/latex/amscc/FKpl.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/FKpl.tex
# Traitement du fichier: ../src/latex/amscc/8qZv.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/8qZv.tex
# Traitement du fichier: ../src/latex/amscc/TMrr.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/TMrr.tex
# Traitement du fichier: ../src/latex/amscc/5sS2.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/5sS2.tex
# Traitement du fichier: ../src/latex/amscc/qjd1.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/qjd1.tex
# Traitement du fichier: ../src/latex/amscc/aiup.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/aiup.tex
# Traitement du fichier: ../src/latex/amscc/PI1u.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/PI1u.tex
# Traitement du fichier: ../src/latex/amscc/3WGA.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/3WGA.tex
# Traitement du fichier: ../src/latex/amscc/Louq.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/Louq.tex
# Traitement du fichier: ../src/latex/amscc/j7Pn.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/j7Pn.tex
# Traitement du fichier: ../src/latex/amscc/Su3X.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/Su3X.tex
# Traitement du fichier: ../src/latex/amscc/SPjU.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/SPjU.tex
# Traitement du fichier: ../src/latex/amscc/rvC6.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/rvC6.tex
# Traitement du fichier: ../src/latex/amscc/mH1D.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/mH1D.tex
# Traitement du fichier: ../src/latex/amscc/1lAn.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/1lAn.tex
# Traitement du fichier: ../src/latex/amscc/aUnN.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/aUnN.tex
# Traitement du fichier: ../src/latex/amscc/kWDX.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/kWDX.tex
# Traitement du fichier: ../src/latex/amscc/xV0R.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/xV0R.tex
# Traitement du fichier: ../src/latex/amscc/Ajfy.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/Ajfy.tex
# Traitement du fichier: ../src/latex/amscc/lZfc.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/lZfc.tex
# Traitement du fichier: ../src/latex/amscc/QqHC.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/QqHC.tex
# Traitement du fichier: ../src/latex/amscc/qZkI.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/qZkI.tex
# Traitement du fichier: ../src/latex/amscc/V97L.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/V97L.tex
# Traitement du fichier: ../src/latex/amscc/aUn2.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/aUn2.tex
# Traitement du fichier: ../src/latex/amscc/taba.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/taba.tex
# Traitement du fichier: ../src/latex/amscc/Kdi9.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/Kdi9.tex
# Traitement du fichier: ../src/latex/amscc/drby.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/drby.tex
# Traitement du fichier: ../src/latex/amscc/7J6y.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/7J6y.tex
# Traitement du fichier: ../src/latex/amscc/4v91.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/4v91.tex
# Traitement du fichier: ../src/latex/amscc/Po88.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/Po88.tex
# Traitement du fichier: ../src/latex/amscc/CXE4.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/CXE4.tex
# Traitement du fichier: ../src/latex/amscc/vnXU.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/vnXU.tex
# Traitement du fichier: ../src/latex/amscc/a40A.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/a40A.tex
# Traitement du fichier: ../src/latex/amscc/uR6d.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/uR6d.tex
# Traitement du fichier: ../src/latex/amscc/w4TW.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/w4TW.tex
# Traitement du fichier: ../src/latex/amscc/5NS7.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/5NS7.tex
# Traitement du fichier: ../src/latex/amscc/vnJs.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/vnJs.tex
# Traitement du fichier: ../src/latex/amscc/XwA0.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/XwA0.tex
# Traitement du fichier: ../src/latex/amscc/4CI9.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/4CI9.tex
# Traitement du fichier: ../src/latex/amscc/eAky.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/eAky.tex
# Traitement du fichier: ../src/latex/amscc/LeO2.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/LeO2.tex
# Traitement du fichier: ../src/latex/amscc/hGun.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/hGun.tex
# Traitement du fichier: ../src/latex/amscc/uGsH.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/uGsH.tex
# Traitement du fichier: ../src/latex/amscc/CXUp.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/CXUp.tex
# Traitement du fichier: ../src/latex/amscc/BZWM.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/BZWM.tex
# Traitement du fichier: ../src/latex/amscc/NIYa.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/NIYa.tex
# Traitement du fichier: ../src/latex/amscc/bPo3.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/bPo3.tex
# Traitement du fichier: ../src/latex/amscc/7mIi.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/7mIi.tex
# Traitement du fichier: ../src/latex/amscc/lCVu.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/lCVu.tex
# Traitement du fichier: ../src/latex/amscc/alNi.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/alNi.tex
# Traitement du fichier: ../src/latex/amscc/GHil.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/GHil.tex
# Traitement du fichier: ../src/latex/amscc/ZBXI.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/ZBXI.tex
# Traitement du fichier: ../src/latex/amscc/HJky.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/HJky.tex
# Traitement du fichier: ../src/latex/amscc/djCi.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/djCi.tex
# Traitement du fichier: ../src/latex/amscc/Qds7.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/Qds7.tex
# Traitement du fichier: ../src/latex/amscc/c5jf.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
# ...
# Traitement du fichier: ../src/latex/amscc/dmDL.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/dmDL.tex
# Traitement du fichier: ../src/latex/amscc/64pg.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/64pg.tex
# Traitement du fichier: ../src/latex/amscc/dCHn.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/dCHn.tex
# Traitement du fichier: ../src/latex/amscc/mDzt.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/mDzt.tex
# Traitement du fichier: ../src/latex/amscc/J4Ag.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/J4Ag.tex
# Traitement du fichier: ../src/latex/amscc/r1il.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/r1il.tex
# Traitement du fichier: ../src/latex/amscc/DMpD.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/DMpD.tex
# Traitement du fichier: ../src/latex/amscc/wO4e.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/wO4e.tex
# Traitement du fichier: ../src/latex/amscc/f63Q.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/f63Q.tex
# Traitement du fichier: ../src/latex/amscc/eTDu.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/eTDu.tex
# Traitement du fichier: ../src/latex/amscc/PPFk.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/PPFk.tex
# Traitement du fichier: ../src/latex/amscc/1asx.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/1asx.tex
# Traitement du fichier: ../src/latex/amscc/z2ZN.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/z2ZN.tex
# Traitement du fichier: ../src/latex/amscc/ptxH.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/ptxH.tex
# Traitement du fichier: ../src/latex/amscc/gLXG.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/gLXG.tex
# Traitement du fichier: ../src/latex/amscc/GDyM.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/GDyM.tex
# Traitement du fichier: ../src/latex/amscc/32ec.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/32ec.tex
# Traitement du fichier: ../src/latex/amscc/hCfF.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/hCfF.tex
# Traitement du fichier: ../src/latex/amscc/M9lT.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/M9lT.tex
# Traitement du fichier: ../src/latex/amscc/vRme.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/vRme.tex
# Traitement du fichier: ../src/latex/amscc/UHns.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/UHns.tex
# Traitement du fichier: ../src/latex/amscc/jK62.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/jK62.tex
# Traitement du fichier: ../src/latex/amscc/aK0v.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/aK0v.tex
# Traitement du fichier: ../src/latex/amscc/tn85.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/tn85.tex
# Traitement du fichier: ../src/latex/amscc/CPgC.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/CPgC.tex
# Traitement du fichier: ../src/latex/amscc/6YTv.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/6YTv.tex
# Traitement du fichier: ../src/latex/amscc/99Xf.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/99Xf.tex
# Traitement du fichier: ../src/latex/amscc/LfqB.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/LfqB.tex
# Traitement du fichier: ../src/latex/amscc/aaap.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/aaap.tex
# Traitement du fichier: ../src/latex/amscc/6YqE.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/6YqE.tex
# Traitement du fichier: ../src/latex/amscc/6Wjb.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/6Wjb.tex
# Traitement du fichier: ../src/latex/amscc/btoa.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/btoa.tex
# Traitement du fichier: ../src/latex/amscc/ElA1.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/ElA1.tex
# Traitement du fichier: ../src/latex/amscc/WmCw.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/WmCw.tex
# Traitement du fichier: ../src/latex/amscc/bOga.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/bOga.tex
# Traitement du fichier: ../src/latex/amscc/wVDA.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/wVDA.tex
# Traitement du fichier: ../src/latex/amscc/M00y.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/M00y.tex
# Traitement du fichier: ../src/latex/amscc/g9JP.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/g9JP.tex
# Traitement du fichier: ../src/latex/amscc/WSXH.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/WSXH.tex
# Traitement du fichier: ../src/latex/amscc/g19x.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/g19x.tex
# Traitement du fichier: ../src/latex/amscc/7otE.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/7otE.tex
# Traitement du fichier: ../src/latex/amscc/1Bdm.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/1Bdm.tex
# Traitement du fichier: ../src/latex/amscc/gfHC.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/gfHC.tex
# Traitement du fichier: ../src/latex/amscc/2Aw2.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/2Aw2.tex
# Traitement du fichier: ../src/latex/amscc/5AIf.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/5AIf.tex
# Traitement du fichier: ../src/latex/amscc/svRW.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/svRW.tex
# Traitement du fichier: ../src/latex/amscc/m5P9.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/m5P9.tex
# Traitement du fichier: ../src/latex/amscc/JuCo.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/JuCo.tex
# Traitement du fichier: ../src/latex/amscc/P9tc.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/P9tc.tex
# Traitement du fichier: ../src/latex/amscc/LXkF.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/LXkF.tex
# Traitement du fichier: ../src/latex/amscc/Ab62.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/Ab62.tex
# Traitement du fichier: ../src/latex/amscc/pGze.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/pGze.tex
# Traitement du fichier: ../src/latex/amscc/t0mY.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/t0mY.tex
# Traitement du fichier: ../src/latex/amscc/vUFN.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/vUFN.tex
# Traitement du fichier: ../src/latex/amscc/EZfx.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/EZfx.tex
# Traitement du fichier: ../src/latex/amscc/FH8I.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/FH8I.tex
# Traitement du fichier: ../src/latex/amscc/0e0x.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/0e0x.tex
# Traitement du fichier: ../src/latex/amscc/9iIv.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/9iIv.tex
# Traitement du fichier: ../src/latex/amscc/iQqS.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/iQqS.tex
# Traitement du fichier: ../src/latex/amscc/qAIw.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/qAIw.tex
# Traitement du fichier: ../src/latex/amscc/j0O1.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/j0O1.tex
# Traitement du fichier: ../src/latex/amscc/mjqR.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/mjqR.tex
# Traitement du fichier: ../src/latex/amscc/ZTjz.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/ZTjz.tex
# Traitement du fichier: ../src/latex/amscc/Bekb.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/Bekb.tex
# Traitement du fichier: ../src/latex/amscc/HqCj.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/HqCj.tex
# Traitement du fichier: ../src/latex/amscc/qyPc.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/qyPc.tex
# Traitement du fichier: ../src/latex/amscc/ad69.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/ad69.tex
# Traitement du fichier: ../src/latex/amscc/I4Tf.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/I4Tf.tex
# Traitement du fichier: ../src/latex/amscc/4Z0U.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/4Z0U.tex
# Traitement du fichier: ../src/latex/amscc/Vss4.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/Vss4.tex
# Traitement du fichier: ../src/latex/amscc/zhq8.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/zhq8.tex
# Traitement du fichier: ../src/latex/amscc/FIgO.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/FIgO.tex
# Traitement du fichier: ../src/latex/amscc/xQe9.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/xQe9.tex
# Traitement du fichier: ../src/latex/amscc/BVLI.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/BVLI.tex
# Traitement du fichier: ../src/latex/amscc/ieFw.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/ieFw.tex
# Traitement du fichier: ../src/latex/amscc/kJz6.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/kJz6.tex
# Traitement du fichier: ../src/latex/amscc/HXRf.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/HXRf.tex
# Traitement du fichier: ../src/latex/amscc/aOYg.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/aOYg.tex
# Traitement du fichier: ../src/latex/amscc/Jiv8.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/Jiv8.tex
# Traitement du fichier: ../src/latex/amscc/b1T2.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/b1T2.tex
# Traitement du fichier: ../src/latex/amscc/CuTJ.tex
# Erreur lors de l'appel à l'API Gemini: 429 Resource has been exhausted (e.g. check quota).
#   Impossible de classifier ../src/latex/amscc/CuTJ.tex
