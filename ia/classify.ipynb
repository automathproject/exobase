# %%
# !pip install dotenv
# Out:
# Requirement already satisfied: dotenv in /home/maximeadmin/anaconda3/envs/mon_env_ia/lib/python3.11/site-packages (0.9.9)
# Requirement already satisfied: python-dotenv in /home/maximeadmin/anaconda3/envs/mon_env_ia/lib/python3.11/site-packages (from dotenv) (1.0.1)

# %%
import google.generativeai as genai
from dotenv import load_dotenv
import os

# Charger les variables d'environnement depuis le fichier .env
load_dotenv()

api_key = os.environ.get("cle_gemini_api")
if not api_key:
    raise ValueError("La clé API n'est pas définie dans le fichier .env. Veuillez configurer la variable 'cle_api'.")

# Configurer le module avec la clé API
genai.configure(api_key=api_key)

# Exemple d'utilisation de l'API
for m in genai.list_models():
    print(m)
# Out:
# Model(name='models/chat-bison-001',
#       base_model_id='',
#       version='001',
#       display_name='PaLM 2 Chat (Legacy)',
#       description='A legacy text-only model optimized for chat conversations',
#       input_token_limit=4096,
#       output_token_limit=1024,
#       supported_generation_methods=['generateMessage', 'countMessageTokens'],
#       temperature=0.25,
#       max_temperature=None,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/text-bison-001',
#       base_model_id='',
#       version='001',
#       display_name='PaLM 2 (Legacy)',
#       description='A legacy model that understands text and generates text as an output',
#       input_token_limit=8196,
#       output_token_limit=1024,
#       supported_generation_methods=['generateText', 'countTextTokens', 'createTunedTextModel'],
#       temperature=0.7,
#       max_temperature=None,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/embedding-gecko-001',
#       base_model_id='',
#       version='001',
#       display_name='Embedding Gecko',
#       description='Obtain a distributed representation of a text.',
#       input_token_limit=1024,
#       output_token_limit=1,
#       supported_generation_methods=['embedText', 'countTextTokens'],
#       temperature=None,
#       max_temperature=None,
#       top_p=None,
#       top_k=None)
# Model(name='models/gemini-1.0-pro-vision-latest',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.0 Pro Vision',
#       description=('The original Gemini 1.0 Pro Vision model version which was optimized for '
#                    'image understanding. Gemini 1.0 Pro Vision was deprecated on July 12, 2024. '
#                    'Move to a newer Gemini version.'),
#       input_token_limit=12288,
#       output_token_limit=4096,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=0.4,
#       max_temperature=None,
#       top_p=1.0,
#       top_k=32)
# Model(name='models/gemini-pro-vision',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.0 Pro Vision',
#       description=('The original Gemini 1.0 Pro Vision model version which was optimized for '
#                    'image understanding. Gemini 1.0 Pro Vision was deprecated on July 12, 2024. '
#                    'Move to a newer Gemini version.'),
#       input_token_limit=12288,
#       output_token_limit=4096,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=0.4,
#       max_temperature=None,
#       top_p=1.0,
#       top_k=32)
# Model(name='models/gemini-1.5-pro-latest',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.5 Pro Latest',
#       description=('Alias that points to the most recent production (non-experimental) release '
#                    'of Gemini 1.5 Pro, our mid-size multimodal model that supports up to 2 '
#                    'million tokens.'),
#       input_token_limit=2000000,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-1.5-pro-001',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.5 Pro 001',
#       description=('Stable version of Gemini 1.5 Pro, our mid-size multimodal model that '
#                    'supports up to 2 million tokens, released in May of 2024.'),
#       input_token_limit=2000000,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens', 'createCachedContent'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=64)
# Model(name='models/gemini-1.5-pro-002',
#       base_model_id='',
#       version='002',
#       display_name='Gemini 1.5 Pro 002',
#       description=('Stable version of Gemini 1.5 Pro, our mid-size multimodal model that '
#                    'supports up to 2 million tokens, released in September of 2024.'),
#       input_token_limit=2000000,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens', 'createCachedContent'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-1.5-pro',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.5 Pro',
#       description=('Stable version of Gemini 1.5 Pro, our mid-size multimodal model that '
#                    'supports up to 2 million tokens, released in May of 2024.'),
#       input_token_limit=2000000,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-1.5-flash-latest',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.5 Flash Latest',
#       description=('Alias that points to the most recent production (non-experimental) release '
#                    'of Gemini 1.5 Flash, our fast and versatile multimodal model for scaling '
#                    'across diverse tasks.'),
#       input_token_limit=1000000,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-1.5-flash-001',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.5 Flash 001',
#       description=('Stable version of Gemini 1.5 Flash, our fast and versatile multimodal model '
#                    'for scaling across diverse tasks, released in May of 2024.'),
#       input_token_limit=1000000,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens', 'createCachedContent'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=64)
# Model(name='models/gemini-1.5-flash-001-tuning',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.5 Flash 001 Tuning',
#       description=('Version of Gemini 1.5 Flash that supports tuning, our fast and versatile '
#                    'multimodal model for scaling across diverse tasks, released in May of 2024.'),
#       input_token_limit=16384,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens', 'createTunedModel'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=64)
# Model(name='models/gemini-1.5-flash',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.5 Flash',
#       description=('Alias that points to the most recent stable version of Gemini 1.5 Flash, our '
#                    'fast and versatile multimodal model for scaling across diverse tasks.'),
#       input_token_limit=1000000,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-1.5-flash-002',
#       base_model_id='',
#       version='002',
#       display_name='Gemini 1.5 Flash 002',
#       description=('Stable version of Gemini 1.5 Flash, our fast and versatile multimodal model '
#                    'for scaling across diverse tasks, released in September of 2024.'),
#       input_token_limit=1000000,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens', 'createCachedContent'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-1.5-flash-8b',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.5 Flash-8B',
#       description=('Stable version of Gemini 1.5 Flash-8B, our smallest and most cost effective '
#                    'Flash model, released in October of 2024.'),
#       input_token_limit=1000000,
#       output_token_limit=8192,
#       supported_generation_methods=['createCachedContent', 'generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-1.5-flash-8b-001',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.5 Flash-8B 001',
#       description=('Stable version of Gemini 1.5 Flash-8B, our smallest and most cost effective '
#                    'Flash model, released in October of 2024.'),
#       input_token_limit=1000000,
#       output_token_limit=8192,
#       supported_generation_methods=['createCachedContent', 'generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-1.5-flash-8b-latest',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.5 Flash-8B Latest',
#       description=('Alias that points to the most recent production (non-experimental) release '
#                    'of Gemini 1.5 Flash-8B, our smallest and most cost effective Flash model, '
#                    'released in October of 2024.'),
#       input_token_limit=1000000,
#       output_token_limit=8192,
#       supported_generation_methods=['createCachedContent', 'generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-1.5-flash-8b-exp-0827',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.5 Flash 8B Experimental 0827',
#       description=('Experimental release (August 27th, 2024) of Gemini 1.5 Flash-8B, our '
#                    'smallest and most cost effective Flash model. Replaced by '
#                    'Gemini-1.5-flash-8b-001 (stable).'),
#       input_token_limit=1000000,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-1.5-flash-8b-exp-0924',
#       base_model_id='',
#       version='001',
#       display_name='Gemini 1.5 Flash 8B Experimental 0924',
#       description=('Experimental release (September 24th, 2024) of Gemini 1.5 Flash-8B, our '
#                    'smallest and most cost effective Flash model. Replaced by '
#                    'Gemini-1.5-flash-8b-001 (stable).'),
#       input_token_limit=1000000,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-2.0-flash-exp',
#       base_model_id='',
#       version='2.0',
#       display_name='Gemini 2.0 Flash Experimental',
#       description='Gemini 2.0 Flash Experimental',
#       input_token_limit=1048576,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens', 'bidiGenerateContent'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-2.0-flash',
#       base_model_id='',
#       version='2.0',
#       display_name='Gemini 2.0 Flash',
#       description='Gemini 2.0 Flash',
#       input_token_limit=1048576,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-2.0-flash-001',
#       base_model_id='',
#       version='2.0',
#       display_name='Gemini 2.0 Flash 001',
#       description=('Stable version of Gemini 2.0 Flash, our fast and versatile multimodal model '
#                    'for scaling across diverse tasks, released in January of 2025.'),
#       input_token_limit=1048576,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-2.0-flash-exp-image-generation',
#       base_model_id='',
#       version='2.0',
#       display_name='Gemini 2.0 Flash (Image Generation) Experimental',
#       description='Gemini 2.0 Flash (Image Generation) Experimental',
#       input_token_limit=1048576,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens', 'bidiGenerateContent'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-2.0-flash-lite-001',
#       base_model_id='',
#       version='2.0',
#       display_name='Gemini 2.0 Flash-Lite 001',
#       description='Stable version of Gemini 2.0 Flash Lite',
#       input_token_limit=1048576,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-2.0-flash-lite',
#       base_model_id='',
#       version='2.0',
#       display_name='Gemini 2.0 Flash-Lite',
#       description='Gemini 2.0 Flash-Lite',
#       input_token_limit=1048576,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-2.0-flash-lite-preview-02-05',
#       base_model_id='',
#       version='preview-02-05',
#       display_name='Gemini 2.0 Flash-Lite Preview 02-05',
#       description='Preview release (February 5th, 2025) of Gemini 2.0 Flash Lite',
#       input_token_limit=1048576,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-2.0-flash-lite-preview',
#       base_model_id='',
#       version='preview-02-05',
#       display_name='Gemini 2.0 Flash-Lite Preview',
#       description='Preview release (February 5th, 2025) of Gemini 2.0 Flash Lite',
#       input_token_limit=1048576,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=40)
# Model(name='models/gemini-2.0-pro-exp',
#       base_model_id='',
#       version='2.0',
#       display_name='Gemini 2.0 Pro Experimental',
#       description='Experimental release (February 5th, 2025) of Gemini 2.0 Pro',
#       input_token_limit=2097152,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=64)
# Model(name='models/gemini-2.0-pro-exp-02-05',
#       base_model_id='',
#       version='2.0',
#       display_name='Gemini 2.0 Pro Experimental 02-05',
#       description='Experimental release (February 5th, 2025) of Gemini 2.0 Pro',
#       input_token_limit=2097152,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=64)
# Model(name='models/gemini-exp-1206',
#       base_model_id='',
#       version='2.0',
#       display_name='Gemini Experimental 1206',
#       description='Experimental release (February 5th, 2025) of Gemini 2.0 Pro',
#       input_token_limit=2097152,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=64)
# Model(name='models/gemini-2.0-flash-thinking-exp-01-21',
#       base_model_id='',
#       version='2.0-exp-01-21',
#       display_name='Gemini 2.0 Flash Thinking Experimental 01-21',
#       description='Experimental release (January 21st, 2025) of Gemini 2.0 Flash Thinking',
#       input_token_limit=1048576,
#       output_token_limit=65536,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=0.7,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=64)
# Model(name='models/gemini-2.0-flash-thinking-exp',
#       base_model_id='',
#       version='2.0-exp-01-21',
#       display_name='Gemini 2.0 Flash Thinking Experimental 01-21',
#       description='Experimental release (January 21st, 2025) of Gemini 2.0 Flash Thinking',
#       input_token_limit=1048576,
#       output_token_limit=65536,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=0.7,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=64)
# Model(name='models/gemini-2.0-flash-thinking-exp-1219',
#       base_model_id='',
#       version='2.0',
#       display_name='Gemini 2.0 Flash Thinking Experimental',
#       description='Gemini 2.0 Flash Thinking Experimental',
#       input_token_limit=1048576,
#       output_token_limit=65536,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=0.7,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=64)
# Model(name='models/learnlm-1.5-pro-experimental',
#       base_model_id='',
#       version='001',
#       display_name='LearnLM 1.5 Pro Experimental',
#       description=('Alias that points to the most recent stable version of Gemini 1.5 Pro, our '
#                    'mid-size multimodal model that supports up to 2 million tokens.'),
#       input_token_limit=32767,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=2.0,
#       top_p=0.95,
#       top_k=64)
# Model(name='models/gemma-3-27b-it',
#       base_model_id='',
#       version='001',
#       display_name='Gemma 3 27B',
#       description='',
#       input_token_limit=131072,
#       output_token_limit=8192,
#       supported_generation_methods=['generateContent', 'countTokens'],
#       temperature=1.0,
#       max_temperature=None,
#       top_p=0.95,
#       top_k=64)
# Model(name='models/embedding-001',
#       base_model_id='',
#       version='001',
#       display_name='Embedding 001',
#       description='Obtain a distributed representation of a text.',
#       input_token_limit=2048,
#       output_token_limit=1,
#       supported_generation_methods=['embedContent'],
#       temperature=None,
#       max_temperature=None,
#       top_p=None,
#       top_k=None)
# Model(name='models/text-embedding-004',
#       base_model_id='',
#       version='004',
#       display_name='Text Embedding 004',
#       description='Obtain a distributed representation of a text.',
#       input_token_limit=2048,
#       output_token_limit=1,
#       supported_generation_methods=['embedContent'],
#       temperature=None,
#       max_temperature=None,
#       top_p=None,
#       top_k=None)
# Model(name='models/gemini-embedding-exp-03-07',
#       base_model_id='',
#       version='exp-03-07',
#       display_name='Gemini Embedding Experimental 03-07',
#       description='Obtain a distributed representation of a text.',
#       input_token_limit=8192,
#       output_token_limit=1,
#       supported_generation_methods=['embedContent'],
#       temperature=None,
#       max_temperature=None,
#       top_p=None,
#       top_k=None)
# Model(name='models/gemini-embedding-exp',
#       base_model_id='',
#       version='exp-03-07',
#       display_name='Gemini Embedding Experimental',
#       description='Obtain a distributed representation of a text.',
#       input_token_limit=8192,
#       output_token_limit=1,
#       supported_generation_methods=['embedContent'],
#       temperature=None,
#       max_temperature=None,
#       top_p=None,
#       top_k=None)
# Model(name='models/aqa',
#       base_model_id='',
#       version='001',
#       display_name='Model that performs Attributed Question Answering.',
#       description=('Model trained to return answers to questions that are grounded in provided '
#                    'sources, along with estimating answerable probability.'),
#       input_token_limit=7168,
#       output_token_limit=1024,
#       supported_generation_methods=['generateAnswer'],
#       temperature=0.2,
#       max_temperature=None,
#       top_p=1.0,
#       top_k=40)
# Model(name='models/imagen-3.0-generate-002',
#       base_model_id='',
#       version='002',
#       display_name='Imagen 3.0 002 model',
#       description='Vertex served Imagen 3.0 002 model',
#       input_token_limit=480,
#       output_token_limit=8192,
#       supported_generation_methods=['predict'],
#       temperature=None,
#       max_temperature=None,
#       top_p=None,
#       top_k=None)

# %%
import google.generativeai as genai
from dotenv import load_dotenv
import os
import json
import glob
import re
import time

# Charger les variables d'environnement depuis le fichier .env
load_dotenv()

api_key = os.environ.get("cle_gemini_api")
if not api_key:
    raise ValueError("La clé API n'est pas définie dans le fichier .env. Veuillez configurer la variable 'cle_api'.")

# Configurer le module avec la clé API
genai.configure(api_key=api_key)

# Sélectionner le modèle
model = genai.GenerativeModel('gemini-1.5-flash')


def load_chapters(json_file):
    """Charge les chapitres et sous-chapitres depuis un fichier JSON."""
    with open(json_file, 'r', encoding='utf-8') as f:
        data = json.load(f)
    return data


def extract_metadata_from_tex(tex_file):
    """Extrait les métadonnées spécifiques des fichiers LaTeX (titre, thème, etc.)"""
    try:
        with open(tex_file, 'r', encoding='utf-8') as f:
            content = f.read()
        
        # Extraction des métadonnées courantes
        metadata = {}
        patterns = {
            "titre": r'\\titre\{([^}]*)\}',
            "theme": r'\\theme\{([^}]*)\}',
            "uuid": r'\\uuid\{([^}]*)\}',
            "auteur": r'\\auteur\{([^}]*)\}',
            "organisation": r'\\organisation\{([^}]*)\}'
        }
        
        for key, pattern in patterns.items():
            match = re.search(pattern, content)
            if match:
                metadata[key] = match.group(1)
        
        return metadata
    except Exception as e:
        print(f"Erreur lors de l'extraction des métadonnées de {tex_file}: {e}")
        return {}


def extract_exercise_content(tex_file):
    """Extrait le contenu pertinent d'un exercice mathématique."""
    try:
        with open(tex_file, 'r', encoding='utf-8') as f:
            content = f.read()
        
        # Extraire le contenu entre \contenu{...}
        contenu_pattern = r'\\contenu\{(.*?)\}'
        contenu_match = re.search(contenu_pattern, content, re.DOTALL)
        
        if contenu_match:
            exercise_content = contenu_match.group(1)
        else:
            # Si pas de balise contenu, prendre tout le fichier
            exercise_content = content
        
        # Extraire les questions et réponses pour mieux comprendre le contexte
        question_pattern = r'\\question\{([^}]*)\}'
        reponse_pattern = r'\\reponse\{([^}]*)\}'
        
        questions = [m.group(1) for m in re.finditer(question_pattern, exercise_content)]
        reponses = [m.group(1) for m in re.finditer(reponse_pattern, exercise_content)]
        
        # Extraire les formules mathématiques (inline et display)
        math_pattern = r'\$(.*?)\$|\$\$(.*?)\$\$'
        math_matches = re.finditer(math_pattern, exercise_content, re.DOTALL)
        formulas = [m.group(1) or m.group(2) for m in math_matches if m.group(1) or m.group(2)]
        
        # Extraire le texte d'introduction (souvent présent dans \texte{...})
        texte_pattern = r'\\texte\{([^}]*)\}'
        texte_match = re.search(texte_pattern, exercise_content)
        intro_text = texte_match.group(1) if texte_match else ""
        
        # Construire un résumé
        summary = {
            "intro": intro_text,
            "questions": questions,
            "reponses": reponses,
            "nb_formules": len(formulas),
            "formules": formulas[:5]  # Garder seulement quelques formules représentatives
        }
        
        return exercise_content, summary
    except Exception as e:
        print(f"Erreur lors de l'extraction du contenu de l'exercice {tex_file}: {e}")
        return "", {}


def classify_tex_with_metadata_first(tex_file, chapters):
    """Stratégie de classification qui privilégie les métadonnées avant tout."""
    print(f"Classification du fichier: {tex_file}")
    
    # 1. Extraire les métadonnées
    metadata = extract_metadata_from_tex(tex_file)
    
    if metadata:
        print(f"  Métadonnées trouvées: {metadata}")
        
        # Si un thème est présent, c'est notre information la plus précieuse
        if "theme" in metadata and metadata["theme"]:
            theme = metadata["theme"]
            print(f"  Thème trouvé: {theme}")
            
            # Construire un prompt spécifique basé sur le thème
            prompt = f"""
            Vous êtes un expert en classification de documents mathématiques. Votre tâche est de déterminer
            le chapitre et le sous-chapitre les plus pertinents pour un exercice mathématique.
            
            Les informations suivantes sont disponibles:
            
            TITRE DE L'EXERCICE: {metadata.get("titre", "Non spécifié")}
            THÈME DE L'EXERCICE: {theme}
            
            Voici une liste de chapitres et sous-chapitres disponibles:
            {json.dumps(chapters, indent=2, ensure_ascii=False)}
            
            Basez-vous principalement sur les mots-clés présents dans le thème pour déterminer le chapitre
            et le sous-chapitre les plus appropriés.
            
            Fournissez votre réponse UNIQUEMENT au format JSON suivant:
            {{
                "chapitre": "Nom du chapitre",
                "sousChapitre": "Nom du sous-chapitre"
            }}
            """
            
            try:
                response = model.generate_content(
                    prompt,
                    generation_config=genai.GenerationConfig(
                        temperature=0.1,
                        top_p=0.95,
                        top_k=40
                    )
                )
                
                response_text = response.text.strip()
                
                # Extraire le JSON 
                json_pattern = r'\{(?:[^{}]|(?:\{(?:[^{}]|(?:\{[^{}]*\}))*\}))*"chapitre"\s*:\s*"[^"]*"\s*,\s*"sousChapitre"\s*:\s*"[^"]*"(?:[^{}]|(?:\{(?:[^{}]|(?:\{[^{}]*\}))*\}))*\}'
                match = re.search(json_pattern, response_text)
                
                if match:
                    json_string = match.group(0)
                    json_string = json_string.replace("`", "")
                    
                    try:
                        classification = json.loads(json_string)
                        if "chapitre" in classification and "sousChapitre" in classification:
                            print(f"  Classification basée sur le thème: {classification['chapitre']} / {classification['sousChapitre']}")
                            return classification["chapitre"], classification["sousChapitre"]
                    except json.JSONDecodeError as e:
                        print(f"  Erreur lors du décodage JSON: {e}")
                
                # Méthode alternative si l'extraction JSON échoue
                chapitre_pattern = r'"chapitre"\s*:\s*"([^"]*)"'
                sousChapitre_pattern = r'"sousChapitre"\s*:\s*"([^"]*)"'
                
                chapitre_match = re.search(chapitre_pattern, response_text)
                sous_chapitre_match = re.search(sousChapitre_pattern, response_text)
                
                if chapitre_match and sous_chapitre_match:
                    chapitre = chapitre_match.group(1)
                    sous_chapitre = sous_chapitre_match.group(1)
                    print(f"  Classification basée sur le thème (méthode alternative): {chapitre} / {sous_chapitre}")
                    return chapitre, sous_chapitre
                    
            except Exception as e:
                print(f"  Erreur lors de l'appel à l'API: {e}")
    
    # 2. Si les métadonnées ne suffisent pas, extraire et analyser le contenu de l'exercice
    print("  Tentative de classification basée sur le contenu de l'exercice...")
    exercise_content, summary = extract_exercise_content(tex_file)
    
    # Construire un nouveau prompt basé sur le contenu de l'exercice
    if exercise_content:
        prompt = f"""
        Vous êtes un expert en classification d'exercices mathématiques. Votre tâche est de déterminer
        le chapitre et le sous-chapitre les plus pertinents pour cet exercice.
        
        TITRE: {metadata.get("titre", "Non spécifié")}
        
        INTRODUCTION DE L'EXERCICE:
        {summary.get("intro", "Non disponible")}
        
        QUESTIONS:
        {json.dumps(summary.get("questions", []), indent=2, ensure_ascii=False)[:1000]}
        
        QUELQUES FORMULES MATHÉMATIQUES:
        {json.dumps(summary.get("formules", []), indent=2, ensure_ascii=False)[:1000]}
        
        Voici une liste de chapitres et sous-chapitres disponibles:
        {json.dumps(chapters, indent=2, ensure_ascii=False)}
        
        Identifiez les concepts mathématiques abordés dans cet exercice et déterminez le chapitre et
        le sous-chapitre les plus appropriés.
        
        Fournissez votre réponse UNIQUEMENT au format JSON suivant:
        {{
            "chapitre": "Nom du chapitre",
            "sousChapitre": "Nom du sous-chapitre"
        }}
        """
        
        try:
            response = model.generate_content(
                prompt,
                generation_config=genai.GenerationConfig(
                    temperature=0.1,
                    top_p=0.95,
                    top_k=40
                )
            )
            
            response_text = response.text.strip()
            
            # Extraire le JSON
            json_pattern = r'\{(?:[^{}]|(?:\{(?:[^{}]|(?:\{[^{}]*\}))*\}))*"chapitre"\s*:\s*"[^"]*"\s*,\s*"sousChapitre"\s*:\s*"[^"]*"(?:[^{}]|(?:\{(?:[^{}]|(?:\{[^{}]*\}))*\}))*\}'
            match = re.search(json_pattern, response_text)
            
            if match:
                json_string = match.group(0)
                json_string = json_string.replace("`", "")
                
                try:
                    classification = json.loads(json_string)
                    if "chapitre" in classification and "sousChapitre" in classification:
                        print(f"  Classification basée sur le contenu: {classification['chapitre']} / {classification['sousChapitre']}")
                        return classification["chapitre"], classification["sousChapitre"]
                except json.JSONDecodeError as e:
                    print(f"  Erreur lors du décodage JSON: {e}")
            
            # Méthode alternative si l'extraction JSON échoue
            chapitre_pattern = r'"chapitre"\s*:\s*"([^"]*)"'
            sousChapitre_pattern = r'"sousChapitre"\s*:\s*"([^"]*)"'
            
            chapitre_match = re.search(chapitre_pattern, response_text)
            sous_chapitre_match = re.search(sousChapitre_pattern, response_text)
            
            if chapitre_match and sous_chapitre_match:
                chapitre = chapitre_match.group(1)
                sous_chapitre = sous_chapitre_match.group(1)
                print(f"  Classification basée sur le contenu (méthode alternative): {chapitre} / {sous_chapitre}")
                return chapitre, sous_chapitre
                
        except Exception as e:
            print(f"  Erreur lors de l'appel à l'API: {e}")
    
    # 3. Si tout échoue, tenter une dernière approche avec tout le contenu brut
    print("  Tentative de classification avec le contenu brut...")
    return classify_raw_tex_file(tex_file, chapters)


def classify_raw_tex_file(tex_file, chapters):
    """
    Classifie directement un fichier .tex brut et retourne le chapitre et sous-chapitre les plus pertinents.
    Version simplifiée qui se concentre sur l'essentiel.
    """
    try:
        # Lire le contenu brut du fichier
        with open(tex_file, 'r', encoding='utf-8') as f:
            raw_content = f.read()
        
        # Si le fichier est très long, prendre un échantillon représentatif
        if len(raw_content) > 20000:
            # Extraire le début (contient souvent des métadonnées importantes)
            start = raw_content[:3000]
            
            # Extraire quelques sections du milieu (contenu principal)
            middle_start = len(raw_content) // 2 - 3000
            middle = raw_content[middle_start:middle_start + 6000]
            
            # Extraire la fin (peut contenir des conclusions)
            end = raw_content[-3000:]
            
            # Combiner les parties avec des séparateurs
            sample_content = f"{start}\n\n[...CONTENU INTERMÉDIAIRE OMIS...]\n\n{middle}\n\n[...CONTENU INTERMÉDIAIRE OMIS...]\n\n{end}"
            
            content_for_classification = sample_content
            print(f"  Fichier volumineux ({len(raw_content)} caractères), utilisation d'un échantillon.")
        else:
            content_for_classification = raw_content
        
        # Prompt spécifique pour les exercices mathématiques
        prompt = f"""
        Vous êtes un expert en classification d'exercices mathématiques.

        Votre tâche est de déterminer le chapitre et le sous-chapitre les plus pertinents pour cet exercice mathématique.
        
        Analysez le code LaTeX brut suivant, en prenant en compte:
        1. Le titre et les métadonnées de l'exercice (spécialement le champ "theme" s'il existe)
        2. Les formules mathématiques présentes dans l'exercice
        3. Les questions posées et les réponses attendues
        4. Le contexte de l'exercice
        
        Voici une liste de chapitres et sous-chapitres possibles:
        {json.dumps(chapters, indent=2, ensure_ascii=False)}

        Document LaTeX à classifier:
        ```latex
        {content_for_classification}
        ```

        Fournissez votre réponse UNIQUEMENT au format JSON suivant:
        {{
            "chapitre": "Nom du chapitre",
            "sousChapitre": "Nom du sous-chapitre"
        }}
        
        Ne fournissez que le JSON sans autre texte.
        """

        max_retries = 3
        delay = 40  # secondes

        for attempt in range(max_retries):
            try:
                response = model.generate_content(
                    prompt,
                    generation_config=genai.GenerationConfig(
                        temperature=0.1,
                        top_p=0.95,
                        top_k=40
                    )
                )
                
                response_text = response.text.strip()
                
                # Utiliser une expression régulière pour trouver un objet JSON
                json_pattern = r'\{(?:[^{}]|(?:\{(?:[^{}]|(?:\{[^{}]*\}))*\}))*"chapitre"\s*:\s*"[^"]*"\s*,\s*"sousChapitre"\s*:\s*"[^"]*"(?:[^{}]|(?:\{(?:[^{}]|(?:\{[^{}]*\}))*\}))*\}'
                
                match = re.search(json_pattern, response_text)
                
                if match:
                    json_string = match.group(0)
                    json_string = json_string.replace("`", "")
                    
                    try:
                        classification = json.loads(json_string)
                        if "chapitre" in classification and "sousChapitre" in classification:
                            print(f"  Classification du contenu brut réussie: {classification['chapitre']} / {classification['sousChapitre']}")
                            return classification["chapitre"], classification["sousChapitre"]
                    except json.JSONDecodeError as e:
                        print(f"  Erreur de décodage JSON: {e}")
                else:
                    # Méthode alternative
                    chapitre_pattern = r'"chapitre"\s*:\s*"([^"]*)"'
                    sousChapitre_pattern = r'"sousChapitre"\s*:\s*"([^"]*)"'
                    
                    chapitre_match = re.search(chapitre_pattern, response_text)
                    sous_chapitre_match = re.search(sousChapitre_pattern, response_text)
                    
                    if chapitre_match and sous_chapitre_match:
                        chapitre = chapitre_match.group(1)
                        sous_chapitre = sous_chapitre_match.group(1)
                        print(f"  Classification du contenu brut réussie (méthode alternative): {chapitre} / {sous_chapitre}")
                        return chapitre, sous_chapitre

            except Exception as e:
                print(f"  Erreur lors de l'appel à l'API (tentative {attempt + 1}/{max_retries}): {e}")
                if "429" in str(e):
                    print(f"  Quota dépassé. Attente de {delay} secondes...")
                    time.sleep(delay)
                    delay *= 2
                else:
                    return None, None

        print(f"  Échec après {max_retries} tentatives.")
        return None, None
    except Exception as e:
        print(f"  Erreur lors du traitement du fichier {tex_file}: {e}")
        return None, None


def check_chapter_info_exists(tex_file):
    """Vérifie si les commandes \\chapitre et \\sousChapitre sont déjà présentes dans le fichier .tex."""
    try:
        with open(tex_file, 'r', encoding='utf-8') as f:
            content = f.read()
            # Recherche des patterns pour \chapitre{...} et \sousChapitre{...}
            chapitre_pattern = r'\\chapitre\{([^}]*)\}'
            sous_chapitre_pattern = r'\\sousChapitre\{([^}]*)\}'
            
            chapitre_match = re.search(chapitre_pattern, content)
            sous_chapitre_match = re.search(sous_chapitre_pattern, content)
            
            if chapitre_match and sous_chapitre_match:
                # Les deux commandes existent déjà
                return True, chapitre_match.group(1), sous_chapitre_match.group(1)
            elif chapitre_match:
                # Seulement \chapitre existe
                return False, chapitre_match.group(1), None
            elif sous_chapitre_match:
                # Seulement \sousChapitre existe
                return False, None, sous_chapitre_match.group(1)
            else:
                # Aucune des commandes n'existe
                return False, None, None
    except Exception as e:
        print(f"Erreur lors de la lecture du fichier {tex_file}: {e}")
        return False, None, None


def insert_chapter_info(tex_file, chapitre, sous_chapitre):
    """Insère ou met à jour les commandes \\chapitre et \\sousChapitre au début du fichier .tex."""
    try:
        # Vérifier si les informations de chapitre sont déjà présentes
        exists, existing_chapitre, existing_sous_chapitre = check_chapter_info_exists(tex_file)
        
        if exists:
            print(f"  Les informations de chapitre sont déjà présentes dans {tex_file}")
            print(f"  Chapitre existant: {existing_chapitre}")
            print(f"  Sous-chapitre existant: {existing_sous_chapitre}")
            return True
        
        # Lire le contenu actuel
        with open(tex_file, 'r', encoding='utf-8') as f:
            content = f.read()
        
        # Si l'un des éléments existe déjà, le supprimer
        if existing_chapitre or existing_sous_chapitre:
            # Supprimer les lignes existantes
            content = re.sub(r'\\chapitre\{[^}]*\}\s*', '', content)
            content = re.sub(r'\\sousChapitre\{[^}]*\}\s*', '', content)
        
        # Réécrire le fichier avec les nouvelles informations au début
        with open(tex_file, 'w', encoding='utf-8') as f:
            f.write(f"\\chapitre{{{chapitre}}}\n")
            f.write(f"\\sousChapitre{{{sous_chapitre}}}\n")
            f.write(content)
        
        return True
    except Exception as e:
        print(f"Erreur lors de l'écriture dans le fichier {tex_file}: {e}")
        return False


def main():
    """Fonction principale pour classifier et insérer les informations dans les fichiers .tex."""
    chapters = load_chapters("../metadata/exo7/chapitres_complet.json")
    tex_files = glob.glob("../src/latex/amscc/*.tex")
    
    # Pour les tests, limiter le nombre de fichiers
    # tex_files = tex_files[:5]  # Décommentez pour tester sur un petit échantillon
    
    total_files = len(tex_files)
    already_classified = 0
    newly_classified = 0
    failed_classification = 0

    print(f"=== DÉBUT DE LA CLASSIFICATION ({total_files} fichiers) ===\n")

    for i, tex_file in enumerate(tex_files):
        print(f"[{i+1}/{total_files}] Traitement du fichier: {tex_file}")
        
        # Vérifier si les informations de chapitre existent déjà
        exists, existing_chapitre, existing_sous_chapitre = check_chapter_info_exists(tex_file)
        
        if exists:
            print(f"  Fichier déjà classifié: {existing_chapitre} / {existing_sous_chapitre}")
            already_classified += 1
            continue
        
        # Utiliser la stratégie optimisée pour les exercices
        chapitre, sous_chapitre = classify_tex_with_metadata_first(tex_file, chapters)

        if chapitre and sous_chapitre:
            print(f"  Classification réussie: {chapitre} / {sous_chapitre}")
            success = insert_chapter_info(tex_file, chapitre, sous_chapitre)
            if success:
                print(f"  ✓ Informations insérées dans {tex_file}")
                newly_classified += 1
            else:
                print(f"  ✗ Échec de l'insertion des informations dans {tex_file}")
                failed_classification += 1
        else:
            print(f"  ✗ Impossible de classifier {tex_file}")
            failed_classification += 1
        
        # Ajouter une pause entre les fichiers pour éviter le rate limiting de l'API
        if i < total_files - 1:
            time.sleep(10)  # Pause d'une seconde
    
    # Afficher un résumé
    print("\n=== RÉSUMÉ DU TRAITEMENT ===")
    print(f"Total des fichiers traités: {total_files}")
    print(f"Fichiers déjà classifiés: {already_classified}")
    print(f"Fichiers nouvellement classifiés: {newly_classified}")
    print(f"Échecs de classification: {failed_classification}")
    
    if total_files - already_classified > 0:
        success_rate = (newly_classified / (total_files - already_classified)) * 100
        print(f"Taux de réussite: {success_rate:.2f}% des fichiers non classifiés")


if __name__ == "__main__":
    main()
# Out:
# === DÉBUT DE LA CLASSIFICATION (458 fichiers) ===
#
# [1/458] Traitement du fichier: ../src/latex/amscc/YBwt.tex
#   Fichier déjà classifié: Probabilité discrète / Lois de distributions
# [2/458] Traitement du fichier: ../src/latex/amscc/trhY.tex
#   Fichier déjà classifié: Statistique / Tests d'hypothèses, intervalle de confiance
# [3/458] Traitement du fichier: ../src/latex/amscc/aWAS.tex
#   Fichier déjà classifié: Développement limité / Calculs
# [4/458] Traitement du fichier: ../src/latex/amscc/DEZs.tex
#   Fichier déjà classifié: Statistique / Tests d'hypothèses, intervalle de confiance
# [5/458] Traitement du fichier: ../src/latex/amscc/5cbY.tex
#   Fichier déjà classifié: Statistique / Tests d'hypothèses, intervalle de confiance
# [6/458] Traitement du fichier: ../src/latex/amscc/ouYw.tex
#   Fichier déjà classifié: Calcul d'intégrales / Autre
# [7/458] Traitement du fichier: ../src/latex/amscc/6NIK.tex
#   Fichier déjà classifié: Probabilité discrète / Lois de distributions
# [8/458] Traitement du fichier: ../src/latex/amscc/PPhD.tex
#   Fichier déjà classifié: Probabilité continue / Densité de probabilité
# [9/458] Traitement du fichier: ../src/latex/amscc/0oHk.tex
#   Fichier déjà classifié: Statistique / Autre
# [10/458] Traitement du fichier: ../src/latex/amscc/hWFx.tex
#   Fichier déjà classifié: Probabilité discrète / Variable aléatoire discrète
# [11/458] Traitement du fichier: ../src/latex/amscc/Uijb.tex
#   Fichier déjà classifié: Interpolation polynomiale / Interpolation polynomiale
# [12/458] Traitement du fichier: ../src/latex/amscc/7aqI.tex
#   Fichier déjà classifié: Statistique / Tests d'hypothèses, intervalle de confiance
# [13/458] Traitement du fichier: ../src/latex/amscc/cEVS.tex
#   Fichier déjà classifié: Série numérique / Série à  termes positifs
# [14/458] Traitement du fichier: ../src/latex/amscc/tNNT.tex
#   Fichier déjà classifié: Probabilité continue / Densité de probabilité
# [15/458] Traitement du fichier: ../src/latex/amscc/gsn9.tex
#   Fichier déjà classifié: Probabilité continue / Densité de probabilité
# [16/458] Traitement du fichier: ../src/latex/amscc/yp7e.tex
#   Fichier déjà classifié: Série numérique / Autre
# [17/458] Traitement du fichier: ../src/latex/amscc/cLt6.tex
#   Fichier déjà classifié: Statistique / Tests d'hypothèses, intervalle de confiance
# [18/458] Traitement du fichier: ../src/latex/amscc/qGRj.tex
#   Fichier déjà classifié: Fonction de plusieurs variables / Extremums locaux
# [19/458] Traitement du fichier: ../src/latex/amscc/Y6X6.tex
#   Fichier déjà classifié: Autre / Autre
# [20/458] Traitement du fichier: ../src/latex/amscc/Stxj.tex
#   Fichier déjà classifié: Série entière / Développement en série entière
# [21/458] Traitement du fichier: ../src/latex/amscc/AKnT.tex
#   Fichier déjà classifié: Autre / Autre
# [22/458] Traitement du fichier: ../src/latex/amscc/BGJz.tex
#   Fichier déjà classifié: Probabilité continue / Densité de probabilité
# [23/458] Traitement du fichier: ../src/latex/amscc/femq.tex
#   Fichier déjà classifié: Déterminant, système linéaire / Calcul de déterminants
# [24/458] Traitement du fichier: ../src/latex/amscc/TwOd.tex
#   Fichier déjà classifié: Probabilité continue / Densité de probabilité
# [25/458] Traitement du fichier: ../src/latex/amscc/kOVx.tex
#   Fichier déjà classifié: Déterminant, système linéaire / Calcul de déterminants
# [26/458] Traitement du fichier: ../src/latex/amscc/tPCs.tex
#   Fichier déjà classifié: Résolution de systèmes linéaires : méthode itérative / Résolution de systèmes linéaires : méthode itérative
# [27/458] Traitement du fichier: ../src/latex/amscc/xTQK.tex
#   Fichier déjà classifié: Interpolation polynomiale / Interpolation polynomiale
# [28/458] Traitement du fichier: ../src/latex/amscc/AS6p.tex
#   Fichier déjà classifié: Série numérique / Autre
# [29/458] Traitement du fichier: ../src/latex/amscc/pfS1.tex
#   Fichier déjà classifié: Statistique / Estimation
# [30/458] Traitement du fichier: ../src/latex/amscc/HojS.tex
#   Fichier déjà classifié: Fonction de plusieurs variables / Autre
# [31/458] Traitement du fichier: ../src/latex/amscc/KfgI.tex
#   Fichier déjà classifié: Suite / Suite définie par une relation de récurrence
# [32/458] Traitement du fichier: ../src/latex/amscc/SfKE.tex
#   Fichier déjà classifié: Série entière / Autre
# [33/458] Traitement du fichier: ../src/latex/amscc/IC6C.tex
#   Fichier déjà classifié: Série numérique / Séries semi-convergentes
# [34/458] Traitement du fichier: ../src/latex/amscc/BA22.tex
#   Fichier déjà classifié: Statistique / Tests d'hypothèses, intervalle de confiance
# [35/458] Traitement du fichier: ../src/latex/amscc/uSXE.tex
#   Fichier déjà classifié: Statistique / Tests d'hypothèses, intervalle de confiance
# [36/458] Traitement du fichier: ../src/latex/amscc/MZkM.tex
#   Fichier déjà classifié: Autre / Autre
# [37/458] Traitement du fichier: ../src/latex/amscc/CLjr.tex
#   Fichier déjà classifié: Polynôme, fraction rationnelle / Racine, décomposition en facteurs irréductibles
# [38/458] Traitement du fichier: ../src/latex/amscc/o5At.tex
#   Fichier déjà classifié: Fonction de plusieurs variables / Extremums locaux
# [39/458] Traitement du fichier: ../src/latex/amscc/dC7P.tex
#   Fichier déjà classifié: Série entière / Calcul de la somme d'une série entière
# [40/458] Traitement du fichier: ../src/latex/amscc/hqXo.tex
#   Fichier déjà classifié: Dérivabilité des fonctions réelles / Calculs
# [41/458] Traitement du fichier: ../src/latex/amscc/H0fC.tex
#   Fichier déjà classifié: Fonction de plusieurs variables / Extremums locaux
# [42/458] Traitement du fichier: ../src/latex/amscc/Xvzc.tex
#   Fichier déjà classifié: Statistique / Tests d'hypothèses, intervalle de confiance
# [43/458] Traitement du fichier: ../src/latex/amscc/NCVL.tex
#   Fichier déjà classifié: Polynôme, fraction rationnelle / Division euclidienne
# [44/458] Traitement du fichier: ../src/latex/amscc/oXIK.tex
# Classification du fichier: ../src/latex/amscc/oXIK.tex
#   Métadonnées trouvées: {'titre': 'Min et Max', 'theme': 'variables aléatoires à densité', 'uuid': 'oXIK', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: variables aléatoires à densité
#   Classification basée sur le thème: Probabilité continue / Densité de probabilité
#   Classification réussie: Probabilité continue / Densité de probabilité
#   ✓ Informations insérées dans ../src/latex/amscc/oXIK.tex
# [45/458] Traitement du fichier: ../src/latex/amscc/5Df5.tex
# Classification du fichier: ../src/latex/amscc/5Df5.tex
#   Métadonnées trouvées: {'titre': ' Distribution normale ', 'theme': 'loi normale', 'uuid': '5Df5', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: loi normale
#   Classification basée sur le thème: Probabilité continue / Loi normale
#   Classification réussie: Probabilité continue / Loi normale
#   ✓ Informations insérées dans ../src/latex/amscc/5Df5.tex
# [46/458] Traitement du fichier: ../src/latex/amscc/AGDn.tex
# Classification du fichier: ../src/latex/amscc/AGDn.tex
#   Métadonnées trouvées: {'titre': 'Calcul de déterminant', 'theme': 'calcul déterminant', 'uuid': 'AGDn', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: calcul déterminant
#   Classification basée sur le thème: Déterminant, système linéaire / Calcul de déterminants
#   Classification réussie: Déterminant, système linéaire / Calcul de déterminants
#   ✓ Informations insérées dans ../src/latex/amscc/AGDn.tex
# [47/458] Traitement du fichier: ../src/latex/amscc/r0au.tex
# Classification du fichier: ../src/latex/amscc/r0au.tex
#   Métadonnées trouvées: {'titre': 'Courbes de niveau', 'theme': 'fonctions de plusieurs variables', 'uuid': 'r0au', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: fonctions de plusieurs variables
#   Classification basée sur le thème: Fonction de plusieurs variables / Autre
#   Classification réussie: Fonction de plusieurs variables / Autre
#   ✓ Informations insérées dans ../src/latex/amscc/r0au.tex
# [48/458] Traitement du fichier: ../src/latex/amscc/ReNe.tex
# Classification du fichier: ../src/latex/amscc/ReNe.tex
#   Métadonnées trouvées: {'titre': 'OPTRN', 'theme': 'réseaux de neurones', 'uuid': 'ReNe', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: réseaux de neurones
#   Classification basée sur le thème: Autre / Autre
#   Classification réussie: Autre / Autre
#   ✓ Informations insérées dans ../src/latex/amscc/ReNe.tex
# [49/458] Traitement du fichier: ../src/latex/amscc/rf0B.tex
# Classification du fichier: ../src/latex/amscc/rf0B.tex
#   Métadonnées trouvées: {'titre': "Définition et propriété d'une probabilité", 'theme': 'probabilités', 'uuid': 'rf0B', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: probabilités
#   Classification basée sur le thème: Probabilité discrète / Définition et propriété d'une probabilité
#   Classification réussie: Probabilité discrète / Définition et propriété d'une probabilité
#   ✓ Informations insérées dans ../src/latex/amscc/rf0B.tex
# [50/458] Traitement du fichier: ../src/latex/amscc/Syo2.tex
# Classification du fichier: ../src/latex/amscc/Syo2.tex
#   Métadonnées trouvées: {'titre': "\\'Etude d'une matrice à paramètres", 'theme': 'calcul matriciel', 'uuid': 'Syo2', 'auteur': 'Maxime NGUYEN', 'organisation': 'AMSCC'}
#   Thème trouvé: calcul matriciel
#   Classification basée sur le thème: Matrice / Propriétés élémentaires, généralités
#   Classification réussie: Matrice / Propriétés élémentaires, généralités
#   ✓ Informations insérées dans ../src/latex/amscc/Syo2.tex
# [51/458] Traitement du fichier: ../src/latex/amscc/bXCC.tex
# Classification du fichier: ../src/latex/amscc/bXCC.tex
#   Métadonnées trouvées: {'titre': "\\'Etude des zéros d'une fonction non linéaire", 'theme': 'méthodes numériques', 'uuid': 'bXCC', 'auteur': 'Alizée GEERAERT', 'organisation': 'AMSCC'}
#   Thème trouvé: méthodes numériques
#   Classification basée sur le thème: Méthodes numériques / Méthode de Newton
#   Classification réussie: Méthodes numériques / Méthode de Newton
#   ✓ Informations insérées dans ../src/latex/amscc/bXCC.tex
# [52/458] Traitement du fichier: ../src/latex/amscc/cpBJ.tex
# Classification du fichier: ../src/latex/amscc/cpBJ.tex
#   Métadonnées trouvées: {'titre': 'Complexes et matrices', 'theme': 'calcul matriciel, nombres complexes', 'uuid': 'cpBJ', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: calcul matriciel, nombres complexes
#   Classification basée sur le thème: Matrice / Propriétés élémentaires, généralités
#   Classification réussie: Matrice / Propriétés élémentaires, généralités
#   ✓ Informations insérées dans ../src/latex/amscc/cpBJ.tex
# [53/458] Traitement du fichier: ../src/latex/amscc/ZVIr.tex
# Classification du fichier: ../src/latex/amscc/ZVIr.tex
#   Métadonnées trouvées: {'titre': 'Calculs de lois', 'theme': 'loi normale', 'uuid': 'ZVIr', 'auteur': 'Maxime NGUYEN', 'organisation': 'AMSCC'}
#   Thème trouvé: loi normale
#   Classification basée sur le thème: Probabilité continue / Loi normale
#   Classification réussie: Probabilité continue / Loi normale
#   ✓ Informations insérées dans ../src/latex/amscc/ZVIr.tex
# [54/458] Traitement du fichier: ../src/latex/amscc/ycEr.tex
# Classification du fichier: ../src/latex/amscc/ycEr.tex
#   Métadonnées trouvées: {'titre': 'Regression linéaire', 'theme': 'optimisation', 'uuid': 'ycEr', 'auteur': 'Erwan HILLION', 'organisation': 'AMSCC'}
#   Thème trouvé: optimisation
#   Classification basée sur le thème: Optimisation / Autre
#   Classification réussie: Optimisation / Autre
#   ✓ Informations insérées dans ../src/latex/amscc/ycEr.tex
# [55/458] Traitement du fichier: ../src/latex/amscc/dsIx.tex
# Classification du fichier: ../src/latex/amscc/dsIx.tex
#   Métadonnées trouvées: {'titre': 'Estimation et loi puissance', 'theme': 'estimateurs, intervalle de confiance', 'uuid': 'dsIx', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: estimateurs, intervalle de confiance
#   Classification basée sur le thème: Statistique / Estimation
#   Classification réussie: Statistique / Estimation
#   ✓ Informations insérées dans ../src/latex/amscc/dsIx.tex
# [56/458] Traitement du fichier: ../src/latex/amscc/MWOk.tex
# Classification du fichier: ../src/latex/amscc/MWOk.tex
#   Métadonnées trouvées: {'titre': 'Etude de séries entières', 'theme': 'séries entières', 'uuid': 'MWOk', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: séries entières
#   Classification basée sur le thème: Série entière / Autre
#   Classification réussie: Série entière / Autre
#   ✓ Informations insérées dans ../src/latex/amscc/MWOk.tex
# [57/458] Traitement du fichier: ../src/latex/amscc/Ueb3.tex
#   Fichier déjà classifié: Probabilité discrète / Variable aléatoire discrète
# [58/458] Traitement du fichier: ../src/latex/amscc/8SbE.tex
# Classification du fichier: ../src/latex/amscc/8SbE.tex
#   Métadonnées trouvées: {'titre': 'Fonction périodique et série de Fourier', 'theme': 'séries de Fourier', 'uuid': '8SbE', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: séries de Fourier
#   Classification basée sur le thème: Série de Fourier / Calcul de coefficients
#   Classification réussie: Série de Fourier / Calcul de coefficients
#   ✓ Informations insérées dans ../src/latex/amscc/8SbE.tex
# [59/458] Traitement du fichier: ../src/latex/amscc/Bs5w.tex
# Classification du fichier: ../src/latex/amscc/Bs5w.tex
#   Métadonnées trouvées: {'titre': "Séries entières solutions d'équations différentielles", 'theme': 'séries entières, équations différentielles', 'uuid': 'Bs5w', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: séries entières, équations différentielles
#   Classification basée sur le thème: Série entière / Equations différentielles
#   Classification réussie: Série entière / Equations différentielles
#   ✓ Informations insérées dans ../src/latex/amscc/Bs5w.tex
# [60/458] Traitement du fichier: ../src/latex/amscc/M7Z5.tex
# Classification du fichier: ../src/latex/amscc/M7Z5.tex
#   Métadonnées trouvées: {'titre': ' Comparaison de moyennes ', 'theme': "tests d'hypothèses", 'uuid': 'M7Z5', 'auteur': 'Maxime Nguyen', 'organisation': 'AMSCC'}
#   Thème trouvé: tests d'hypothèses
#   Classification basée sur le thème: Statistique / Tests d'hypothèses, intervalle de confiance
#   Classification réussie: Statistique / Tests d'hypothèses, intervalle de confiance
#   ✓ Informations insérées dans ../src/latex/amscc/M7Z5.tex
# [61/458] Traitement du fichier: ../src/latex/amscc/5hoU.tex
#   Fichier déjà classifié: Topologie / Ouvert, fermé, intérieur, adhérence
# [62/458] Traitement du fichier: ../src/latex/amscc/WCGV.tex
# Classification du fichier: ../src/latex/amscc/WCGV.tex
#   Métadonnées trouvées: {'titre': 'Fiabilité', 'theme': 'variables aléatoires discrètes, loi binomiale', 'uuid': 'WCGV', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: variables aléatoires discrètes, loi binomiale
#   Classification basée sur le thème: Probabilité discrète / Lois de distributions
#   Classification réussie: Probabilité discrète / Lois de distributions
#   ✓ Informations insérées dans ../src/latex/amscc/WCGV.tex
# [63/458] Traitement du fichier: ../src/latex/amscc/ZT9T.tex
#   Fichier déjà classifié: Probabilité continue / Densité de probabilité
# [64/458] Traitement du fichier: ../src/latex/amscc/JPjn.tex
#   Fichier déjà classifié: Probabilité continue / Densité de probabilité
# [65/458] Traitement du fichier: ../src/latex/amscc/Sqjo.tex
# Classification du fichier: ../src/latex/amscc/Sqjo.tex
#   Métadonnées trouvées: {'titre': 'Test de consommation ', 'theme': "tests d'hypothèses", 'uuid': 'Sqjo', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: tests d'hypothèses
#   Classification basée sur le thème: Statistique / Tests d'hypothèses, intervalle de confiance
#   Classification réussie: Statistique / Tests d'hypothèses, intervalle de confiance
#   ✓ Informations insérées dans ../src/latex/amscc/Sqjo.tex
# [66/458] Traitement du fichier: ../src/latex/amscc/PUWY.tex
#   Fichier déjà classifié: Série numérique / Convergence absolue
# [67/458] Traitement du fichier: ../src/latex/amscc/fGoC.tex
#   Fichier déjà classifié: Statistique / Estimation
# [68/458] Traitement du fichier: ../src/latex/amscc/5FLs.tex
# Classification du fichier: ../src/latex/amscc/5FLs.tex
#   Métadonnées trouvées: {'titre': "Test d'indépendance", 'theme': "statistiques, tests d'hypothèses", 'uuid': '5FLs', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: statistiques, tests d'hypothèses
#   Classification basée sur le thème: Statistique / Tests d'hypothèses, intervalle de confiance
#   Classification réussie: Statistique / Tests d'hypothèses, intervalle de confiance
#   ✓ Informations insérées dans ../src/latex/amscc/5FLs.tex
# [69/458] Traitement du fichier: ../src/latex/amscc/0uqI.tex
# Classification du fichier: ../src/latex/amscc/0uqI.tex
#   Métadonnées trouvées: {'titre': 'Optimisation par approximation', 'theme': 'variables aléatoires, théorème central limite', 'uuid': '0uqI', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: variables aléatoires, théorème central limite
#   Classification basée sur le thème: Probabilité continue / Lois des grands nombres, théorème central limite
#   Classification réussie: Probabilité continue / Lois des grands nombres, théorème central limite
#   ✓ Informations insérées dans ../src/latex/amscc/0uqI.tex
# [70/458] Traitement du fichier: ../src/latex/amscc/653s.tex
# Classification du fichier: ../src/latex/amscc/653s.tex
#   Métadonnées trouvées: {'titre': ' Réseau de neurones multicouches ', 'theme': 'réseaux de neurones', 'uuid': '653s', 'auteur': ' Maxime NGUYEN ', 'organisation': ' AMSCC '}
#   Thème trouvé: réseaux de neurones
#   Classification basée sur le thème: Autre / Autre
#   Classification réussie: Autre / Autre
#   ✓ Informations insérées dans ../src/latex/amscc/653s.tex
# [71/458] Traitement du fichier: ../src/latex/amscc/5gPB.tex
# Classification du fichier: ../src/latex/amscc/5gPB.tex
#   Métadonnées trouvées: {'titre': "\\'Etude d'un schéma numérique", 'theme': 'méthodes numériques, équations différentielles', 'uuid': '5gPB', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: méthodes numériques, équations différentielles
#   Classification basée sur le thème: Equation différentielle / Résolution d'équation différentielle
#   Classification réussie: Equation différentielle / Résolution d'équation différentielle
#   ✓ Informations insérées dans ../src/latex/amscc/5gPB.tex
# [72/458] Traitement du fichier: ../src/latex/amscc/tSoF.tex
# Classification du fichier: ../src/latex/amscc/tSoF.tex
#   Métadonnées trouvées: {'titre': 'Equivalents simples', 'theme': 'limite', 'uuid': 'tSoF', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: limite
#   Classification basée sur le thème: Continuité, limite et étude de fonctions réelles / Fonctions équivalentes, fonctions négligeables
#   Classification réussie: Continuité, limite et étude de fonctions réelles / Fonctions équivalentes, fonctions négligeables
#   ✓ Informations insérées dans ../src/latex/amscc/tSoF.tex
# [73/458] Traitement du fichier: ../src/latex/amscc/vt62.tex
# Classification du fichier: ../src/latex/amscc/vt62.tex
#   Métadonnées trouvées: {'titre': 'Inversiblité de matrice', 'theme': 'calcul matriciel', 'uuid': 'vt62', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: calcul matriciel
#   Classification basée sur le thème: Matrice / Inverse, méthode de Gauss
#   Classification réussie: Matrice / Inverse, méthode de Gauss
#   ✓ Informations insérées dans ../src/latex/amscc/vt62.tex
# [74/458] Traitement du fichier: ../src/latex/amscc/qNxE.tex
# Classification du fichier: ../src/latex/amscc/qNxE.tex
#   Métadonnées trouvées: {'titre': 'Simulation de loi : Rademacher, Laplace, Géométrique', 'theme': 'variables aléatoires à densité, simulation de loi', 'uuid': 'qNxE', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: variables aléatoires à densité, simulation de loi
#   Classification basée sur le thème: Probabilité continue / Densité de probabilité
#   Classification réussie: Probabilité continue / Densité de probabilité
#   ✓ Informations insérées dans ../src/latex/amscc/qNxE.tex
# [75/458] Traitement du fichier: ../src/latex/amscc/rhUy.tex
# Classification du fichier: ../src/latex/amscc/rhUy.tex
#   Métadonnées trouvées: {'titre': 'Comparaison de moyennes', 'theme': "tests d'hypothèses", 'uuid': 'rhUy', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: tests d'hypothèses
#   Classification basée sur le thème: Statistique / Tests d'hypothèses, intervalle de confiance
#   Classification réussie: Statistique / Tests d'hypothèses, intervalle de confiance
#   ✓ Informations insérées dans ../src/latex/amscc/rhUy.tex
# [76/458] Traitement du fichier: ../src/latex/amscc/9MyW.tex
# Classification du fichier: ../src/latex/amscc/9MyW.tex
#   Métadonnées trouvées: {'titre': 'Loi de Poisson', 'theme': 'variables aléatoires discrètes, loi de Poisson', 'uuid': '9MyW', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: variables aléatoires discrètes, loi de Poisson
#   Classification basée sur le thème: Probabilité discrète / Lois de distributions
#   Classification réussie: Probabilité discrète / Lois de distributions
#   ✓ Informations insérées dans ../src/latex/amscc/9MyW.tex
# [77/458] Traitement du fichier: ../src/latex/amscc/Cefu.tex
# Classification du fichier: ../src/latex/amscc/Cefu.tex
#   Métadonnées trouvées: {'titre': 'Vrai ou faux', 'theme': 'séries', 'uuid': 'Cefu', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: séries
#   Classification basée sur le thème: Série numérique / Autre
#   Classification réussie: Série numérique / Autre
#   ✓ Informations insérées dans ../src/latex/amscc/Cefu.tex
# [78/458] Traitement du fichier: ../src/latex/amscc/MPPL.tex
# Classification du fichier: ../src/latex/amscc/MPPL.tex
#   Métadonnées trouvées: {'titre': 'Matrices inversibles', 'theme': 'calcul déterminant', 'uuid': 'MPPL', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: calcul déterminant
#   Classification basée sur le thème: Déterminant, système linéaire / Calcul de déterminants
#   Classification réussie: Déterminant, système linéaire / Calcul de déterminants
#   ✓ Informations insérées dans ../src/latex/amscc/MPPL.tex
# [79/458] Traitement du fichier: ../src/latex/amscc/f4ze.tex
# Classification du fichier: ../src/latex/amscc/f4ze.tex
#   Métadonnées trouvées: {'titre': "Résolution d'une équation différentielle", 'theme': 'équations différentielles, séries entières', 'uuid': 'f4ze', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: équations différentielles, séries entières
#   Classification basée sur le thème: Série entière / Equations différentielles
#   Classification réussie: Série entière / Equations différentielles
#   ✓ Informations insérées dans ../src/latex/amscc/f4ze.tex
# [80/458] Traitement du fichier: ../src/latex/amscc/tPHB.tex
# Classification du fichier: ../src/latex/amscc/tPHB.tex
#   Métadonnées trouvées: {'titre': " Calcul d'une somme de série entière", 'uuid': 'tPHB', 'auteur': ' ', 'organisation': ' AMSCC '}
#   Tentative de classification basée sur le contenu de l'exercice...
#   Classification basée sur le contenu: Série entière / Calcul de la somme d'une série entière
#   Classification réussie: Série entière / Calcul de la somme d'une série entière
#   ✓ Informations insérées dans ../src/latex/amscc/tPHB.tex
# [81/458] Traitement du fichier: ../src/latex/amscc/DkOf.tex
# Classification du fichier: ../src/latex/amscc/DkOf.tex
#   Métadonnées trouvées: {'titre': "Test d'adéquation à une loi", 'theme': 'statistiques', 'uuid': 'DkOf', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: statistiques
#   Classification basée sur le thème: Statistique / Tests d'hypothèses, intervalle de confiance
#   Classification réussie: Statistique / Tests d'hypothèses, intervalle de confiance
#   ✓ Informations insérées dans ../src/latex/amscc/DkOf.tex
# [82/458] Traitement du fichier: ../src/latex/amscc/Fe1h.tex
# Classification du fichier: ../src/latex/amscc/Fe1h.tex
#   Métadonnées trouvées: {'titre': 'Déterminant de Vandermonde', 'theme': 'calcul déterminant', 'uuid': 'Fe1h', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: calcul déterminant
#   Classification basée sur le thème: Déterminant, système linéaire / Calcul de déterminants
#   Classification réussie: Déterminant, système linéaire / Calcul de déterminants
#   ✓ Informations insérées dans ../src/latex/amscc/Fe1h.tex
# [83/458] Traitement du fichier: ../src/latex/amscc/Z8Dq.tex
# Classification du fichier: ../src/latex/amscc/Z8Dq.tex
#   Métadonnées trouvées: {'titre': 'Moments de la loi exponentielle', 'theme': 'variables aléatoires à densité', 'uuid': 'Z8Dq', 'auteur': 'Maxime NGUYEN', 'organisation': 'AMSCC'}
#   Thème trouvé: variables aléatoires à densité
#   Classification basée sur le thème: Probabilité continue / Densité de probabilité
#   Classification réussie: Probabilité continue / Densité de probabilité
#   ✓ Informations insérées dans ../src/latex/amscc/Z8Dq.tex
# [84/458] Traitement du fichier: ../src/latex/amscc/mVsg.tex
# Classification du fichier: ../src/latex/amscc/mVsg.tex
#   Métadonnées trouvées: {'titre': "Consommation d'oxygène", 'theme': "tests d'hypothèses", 'uuid': 'mVsg', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: tests d'hypothèses
#   Classification basée sur le thème: Statistique / Tests d'hypothèses, intervalle de confiance
#   Classification réussie: Statistique / Tests d'hypothèses, intervalle de confiance
#   ✓ Informations insérées dans ../src/latex/amscc/mVsg.tex
# [85/458] Traitement du fichier: ../src/latex/amscc/ebva.tex
# Classification du fichier: ../src/latex/amscc/ebva.tex
#   Métadonnées trouvées: {'titre': "Un problème d'extrema", 'theme': 'optimisation', 'uuid': 'ebva', 'auteur': 'Jean-François Culus', 'organisation': 'AMSCC'}
#   Thème trouvé: optimisation
#   Classification basée sur le thème: Fonction de plusieurs variables / Extremums locaux
#   Classification réussie: Fonction de plusieurs variables / Extremums locaux
#   ✓ Informations insérées dans ../src/latex/amscc/ebva.tex
# [86/458] Traitement du fichier: ../src/latex/amscc/O5Wz.tex
# Classification du fichier: ../src/latex/amscc/O5Wz.tex
#   Métadonnées trouvées: {'titre': 'Temps de fonctionnement de machines', 'theme': 'variables aléatoires à densité, loi exponentielle', 'uuid': 'O5Wz', 'auteur': ' ', 'organisation': ' AMSCC '}
#   Thème trouvé: variables aléatoires à densité, loi exponentielle
#   Classification basée sur le thème: Probabilité continue / Densité de probabilité
#   Classification réussie: Probabilité continue / Densité de probabilité
#   ✓ Informations insérées dans ../src/latex/amscc/O5Wz.tex
# [87/458] Traitement du fichier: ../src/latex/amscc/wlig.tex
# Classification du fichier: ../src/latex/amscc/wlig.tex
#   Métadonnées trouvées: {'titre': 'Optimisation sous contrainte (3)', 'theme': 'optimisation', 'uuid': 'wlig', 'auteur': 'Jean-François Culus', 'organisation': 'AMSCC'}
#   Thème trouvé: optimisation
#   Classification basée sur le thème: Fonction convexe / Multiplicateurs de Lagrange
#   Classification réussie: Fonction convexe / Multiplicateurs de Lagrange
#   ✓ Informations insérées dans ../src/latex/amscc/wlig.tex
# [88/458] Traitement du fichier: ../src/latex/amscc/z0hC.tex
# Classification du fichier: ../src/latex/amscc/z0hC.tex
#   Métadonnées trouvées: {'titre': 'Inversibilité de matrices', 'theme': 'calcul matriciel', 'uuid': 'z0hC', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: calcul matriciel
#   Classification basée sur le thème: Matrice / Inverse, méthode de Gauss
#   Classification réussie: Matrice / Inverse, méthode de Gauss
#   ✓ Informations insérées dans ../src/latex/amscc/z0hC.tex
# [89/458] Traitement du fichier: ../src/latex/amscc/kzan.tex
# Classification du fichier: ../src/latex/amscc/kzan.tex
#   Métadonnées trouvées: {'titre': "Convergence d'une suite de variables aléatoires", 'theme': 'loi normale, convergence en loi, fonction caractéristique', 'uuid': 'kzan', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: loi normale, convergence en loi, fonction caractéristique
#   Classification basée sur le thème: Probabilité continue / Convergence en loi
#   Classification réussie: Probabilité continue / Convergence en loi
#   ✓ Informations insérées dans ../src/latex/amscc/kzan.tex
# [90/458] Traitement du fichier: ../src/latex/amscc/Z6wd.tex
# Classification du fichier: ../src/latex/amscc/Z6wd.tex
#   Métadonnées trouvées: {'titre': 'Méthode des moindres carrés', 'theme': 'calcul différentiel, optimisation', 'uuid': 'Z6wd', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: calcul différentiel, optimisation
#   Classification basée sur le thème: Dérivabilité des fonctions réelles / Applications
#   Classification réussie: Dérivabilité des fonctions réelles / Applications
#   ✓ Informations insérées dans ../src/latex/amscc/Z6wd.tex
# [91/458] Traitement du fichier: ../src/latex/amscc/4R9m.tex
# Classification du fichier: ../src/latex/amscc/4R9m.tex
#   Métadonnées trouvées: {'titre': 'Courbes de niveaux', 'theme': 'fonctions de plusieurs variables, courbes de niveaux', 'uuid': '4R9m', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: fonctions de plusieurs variables, courbes de niveaux
#   Classification basée sur le thème: Fonction de plusieurs variables / Courbes de niveaux
#   Classification réussie: Fonction de plusieurs variables / Courbes de niveaux
#   ✓ Informations insérées dans ../src/latex/amscc/4R9m.tex
# [92/458] Traitement du fichier: ../src/latex/amscc/Hhtu.tex
# Classification du fichier: ../src/latex/amscc/Hhtu.tex
#   Métadonnées trouvées: {'titre': "Probabilité d'événements", 'theme': 'probabilités', 'uuid': 'Hhtu', 'auteur': ' ', 'organisation': 'AMSCC'}
#   Thème trouvé: probabilités
#   Classification basée sur le thème: Probabilité discrète / Probabilité et dénombrement
#   Classification réussie: Probabilité discrète / Probabilité et dénombrement
#   ✓ Informations insérées dans ../src/latex/amscc/Hhtu.tex
# [93/458] Traitement du fichier: ../src/latex/amscc/buE8.tex
# Classification du fichier: ../src/latex/amscc/buE8.tex
#   Métadonnées trouvées: {'titre': " Choix d'estimateur", 'theme': 'statistiques, estimateurs, maximum de vraisemblance', 'uuid': 'buE8', 'auteur': 'Maxime NGUYEN', 'organisation': 'AMSCC'}
#   Thème trouvé: statistiques, estimateurs, maximum de vraisemblance
#   Classification basée sur le thème: Statistique / Estimation
#   Classification réussie: Statistique / Estimation
#   ✓ Informations insérées dans ../src/latex/amscc/buE8.tex
# [94/458] Traitement du fichier: ../src/latex/amscc/yTDM.tex
# Classification du fichier: ../src/latex/amscc/yTDM.tex
#   Métadonnées trouvées: {'titre': 'Changement de variable', 'theme': 'variables aléatoires à densité', 'uuid': 'yTDM', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: variables aléatoires à densité
#   Classification basée sur le thème: Probabilité continue / Densité de probabilité
#   Classification réussie: Probabilité continue / Densité de probabilité
#   ✓ Informations insérées dans ../src/latex/amscc/yTDM.tex
# [95/458] Traitement du fichier: ../src/latex/amscc/HvSs.tex
# Classification du fichier: ../src/latex/amscc/HvSs.tex
#   Métadonnées trouvées: {'titre': 'Calcul de probabilités', 'theme': 'théorème central limite, loi normale', 'uuid': 'HvSs', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: théorème central limite, loi normale
#   Classification basée sur le thème: Probabilité continue / Loi normale
#   Classification réussie: Probabilité continue / Loi normale
#   ✓ Informations insérées dans ../src/latex/amscc/HvSs.tex
# [96/458] Traitement du fichier: ../src/latex/amscc/nSDY.tex
# Classification du fichier: ../src/latex/amscc/nSDY.tex
#   Métadonnées trouvées: {'titre': 'Calcul de probabilité', 'theme': 'probabilités', 'uuid': 'phsf', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: probabilités
#   Classification basée sur le thème: Probabilité discrète / Probabilité et dénombrement
#   Classification réussie: Probabilité discrète / Probabilité et dénombrement
#   ✓ Informations insérées dans ../src/latex/amscc/nSDY.tex
# [97/458] Traitement du fichier: ../src/latex/amscc/C5Fq.tex
# Classification du fichier: ../src/latex/amscc/C5Fq.tex
#   Métadonnées trouvées: {'titre': "Simulation d'une loi normale", 'theme': 'loi normale, simulation de loi', 'uuid': 'C5Fq', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: loi normale, simulation de loi
#   Classification basée sur le thème: Probabilité continue / Loi normale
#   Classification réussie: Probabilité continue / Loi normale
#   ✓ Informations insérées dans ../src/latex/amscc/C5Fq.tex
# [98/458] Traitement du fichier: ../src/latex/amscc/TgsV.tex
# Classification du fichier: ../src/latex/amscc/TgsV.tex
#   Métadonnées trouvées: {'titre': 'Probabilités conditionnelles et indépendance', 'theme': 'probabilités conditionnelles', 'uuid': 'TgsV', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: probabilités conditionnelles
#   Classification basée sur le thème: Probabilité discrète / Probabilité conditionnelle
#   Classification réussie: Probabilité discrète / Probabilité conditionnelle
#   ✓ Informations insérées dans ../src/latex/amscc/TgsV.tex
# [99/458] Traitement du fichier: ../src/latex/amscc/nSSt.tex
# Classification du fichier: ../src/latex/amscc/nSSt.tex
#   Métadonnées trouvées: {'titre': 'Problème concret', 'theme': 'optimisation', 'uuid': 'nSSt', 'auteur': 'Jean-François Culus', 'organisation': 'AMSCC'}
#   Thème trouvé: optimisation
#   Classification basée sur le thème: Fonction de plusieurs variables / Extremums locaux
#   Classification réussie: Fonction de plusieurs variables / Extremums locaux
#   ✓ Informations insérées dans ../src/latex/amscc/nSSt.tex
# [100/458] Traitement du fichier: ../src/latex/amscc/XtkF.tex
# Classification du fichier: ../src/latex/amscc/XtkF.tex
#   Métadonnées trouvées: {'titre': "Etude d'extrema", 'theme': 'calcul différentiel, optimisation', 'uuid': 'XtkF', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: calcul différentiel, optimisation
#   Classification basée sur le thème: Fonction de plusieurs variables / Extremums locaux
#   Classification réussie: Fonction de plusieurs variables / Extremums locaux
#   ✓ Informations insérées dans ../src/latex/amscc/XtkF.tex
# [101/458] Traitement du fichier: ../src/latex/amscc/nsgN.tex
# Classification du fichier: ../src/latex/amscc/nsgN.tex
#   Métadonnées trouvées: {'titre': ' Corrélation entre deux valeurs ', 'theme': 'statistiques', 'uuid': 'nsgN', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: statistiques
#   Classification basée sur le thème: Statistique / Autre
#   Classification réussie: Statistique / Autre
#   ✓ Informations insérées dans ../src/latex/amscc/nsgN.tex
# [102/458] Traitement du fichier: ../src/latex/amscc/YIXX.tex
# Classification du fichier: ../src/latex/amscc/YIXX.tex
#   Métadonnées trouvées: {'titre': "Changement de variables d'un couple", 'theme': 'variables aléatoires à densité, loi conjointe', 'uuid': 'YIXX', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: variables aléatoires à densité, loi conjointe
#   Classification basée sur le thème: Probabilité continue / Densité de probabilité
#   Classification réussie: Probabilité continue / Densité de probabilité
#   ✓ Informations insérées dans ../src/latex/amscc/YIXX.tex
# [103/458] Traitement du fichier: ../src/latex/amscc/jj3V.tex
# Classification du fichier: ../src/latex/amscc/jj3V.tex
#   Métadonnées trouvées: {'titre': " Estimation d'une moyenne ", 'theme': 'estimateurs, intervalle de confiance', 'uuid': 'jj3V', 'auteur': 'Maxime NGUYEN', 'organisation': 'AMSCC'}
#   Thème trouvé: estimateurs, intervalle de confiance
#   Classification basée sur le thème: Statistique / Estimation
#   Classification réussie: Statistique / Estimation
#   ✓ Informations insérées dans ../src/latex/amscc/jj3V.tex
# [104/458] Traitement du fichier: ../src/latex/amscc/UDat.tex
# Classification du fichier: ../src/latex/amscc/UDat.tex
#   Métadonnées trouvées: {'titre': 'Indépendance', 'theme': 'probabilités', 'uuid': 'UDat', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: probabilités
#   Classification basée sur le thème: Probabilité discrète / Loi, indépendance, loi conditionnelle
#   Classification réussie: Probabilité discrète / Loi, indépendance, loi conditionnelle
#   ✓ Informations insérées dans ../src/latex/amscc/UDat.tex
# [105/458] Traitement du fichier: ../src/latex/amscc/4Idt.tex
# Classification du fichier: ../src/latex/amscc/4Idt.tex
#   Métadonnées trouvées: {'titre': 'Inégalités et loi de Poisson', 'theme': 'variables aléatoires, loi de Poisson', 'uuid': '4Idt', 'auteur': 'Maxime Nguyen', 'organisation': 'AMSCC'}
#   Thème trouvé: variables aléatoires, loi de Poisson
#   Classification basée sur le thème: Probabilité discrète / Lois de distributions
#   Classification réussie: Probabilité discrète / Lois de distributions
#   ✓ Informations insérées dans ../src/latex/amscc/4Idt.tex
# [106/458] Traitement du fichier: ../src/latex/amscc/yNs9.tex
# Classification du fichier: ../src/latex/amscc/yNs9.tex
#   Métadonnées trouvées: {'titre': 'Division euclidienne et fractions rationnelles', 'theme': 'fractions rationnelles', 'uuid': 'yNs9', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: fractions rationnelles
#   Classification basée sur le thème: Polynôme, fraction rationnelle / Fraction rationnelle
#   Classification réussie: Polynôme, fraction rationnelle / Fraction rationnelle
#   ✓ Informations insérées dans ../src/latex/amscc/yNs9.tex
# [107/458] Traitement du fichier: ../src/latex/amscc/UbhS.tex
# Classification du fichier: ../src/latex/amscc/UbhS.tex
#   Métadonnées trouvées: {'titre': 'Indépendance de variables aléatoires', 'theme': 'variables aléatoires discrètes', 'uuid': 'UbhS', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: variables aléatoires discrètes
#   Classification basée sur le thème: Probabilité discrète / Variable aléatoire discrète
#   Classification réussie: Probabilité discrète / Variable aléatoire discrète
#   ✓ Informations insérées dans ../src/latex/amscc/UbhS.tex
# [108/458] Traitement du fichier: ../src/latex/amscc/EXyV.tex
# Classification du fichier: ../src/latex/amscc/EXyV.tex
#   Métadonnées trouvées: {'titre': 'Fonctions périodiques et coefficients de Fourier', 'theme': 'séries de Fourier', 'uuid': 'EXyV', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: séries de Fourier
#   Classification basée sur le thème: Série de Fourier / Calcul de coefficients
#   Classification réussie: Série de Fourier / Calcul de coefficients
#   ✓ Informations insérées dans ../src/latex/amscc/EXyV.tex
# [109/458] Traitement du fichier: ../src/latex/amscc/9oDf.tex
# Classification du fichier: ../src/latex/amscc/9oDf.tex
#   Métadonnées trouvées: {'titre': "Développement en série entière d'une fonction", 'theme': 'séries entières', 'uuid': '9oDf', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: séries entières
#   Classification basée sur le thème: Série entière / Développement en série entière
#   Classification réussie: Série entière / Développement en série entière
#   ✓ Informations insérées dans ../src/latex/amscc/9oDf.tex
# [110/458] Traitement du fichier: ../src/latex/amscc/6er6.tex
# Classification du fichier: ../src/latex/amscc/6er6.tex
#   Métadonnées trouvées: {'titre': 'Calculs avec une loi normale', 'theme': 'loi normale', 'uuid': '6er6', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: loi normale
#   Classification basée sur le thème: Probabilité continue / Loi normale
#   Classification réussie: Probabilité continue / Loi normale
#   ✓ Informations insérées dans ../src/latex/amscc/6er6.tex
# [111/458] Traitement du fichier: ../src/latex/amscc/wjwa.tex
# Classification du fichier: ../src/latex/amscc/wjwa.tex
#   Métadonnées trouvées: {'titre': 'Démonstration de cours sur la fonction de répartition', 'theme': 'variables aléatoires', 'uuid': 'wjwa', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: variables aléatoires
#   Classification basée sur le thème: Probabilité continue / Densité de probabilité
#   Classification réussie: Probabilité continue / Densité de probabilité
#   ✓ Informations insérées dans ../src/latex/amscc/wjwa.tex
# [112/458] Traitement du fichier: ../src/latex/amscc/tSVB.tex
# Classification du fichier: ../src/latex/amscc/tSVB.tex
#   Métadonnées trouvées: {'titre': 'Modélisation et rencontre de généraux', 'theme': 'variables aléatoires à densité', 'uuid': 'tSVB', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: variables aléatoires à densité
#   Classification basée sur le thème: Probabilité continue / Densité de probabilité
#   Classification réussie: Probabilité continue / Densité de probabilité
#   ✓ Informations insérées dans ../src/latex/amscc/tSVB.tex
# [113/458] Traitement du fichier: ../src/latex/amscc/sPl1.tex
# Classification du fichier: ../src/latex/amscc/sPl1.tex
#   Métadonnées trouvées: {'titre': 'Inversibilité de matrices', 'theme': 'calcul matriciel', 'uuid': 'sPl1', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: calcul matriciel
#   Classification basée sur le thème: Matrice / Inverse, méthode de Gauss
#   Classification réussie: Matrice / Inverse, méthode de Gauss
#   ✓ Informations insérées dans ../src/latex/amscc/sPl1.tex
# [114/458] Traitement du fichier: ../src/latex/amscc/A2Gl.tex
# Classification du fichier: ../src/latex/amscc/A2Gl.tex
#   Métadonnées trouvées: {'titre': 'Loi de Poisson et estimation par maximum de vraisemblance', 'theme': 'statistiques, loi de Poisson, estimateurs, maximum de vraisemblance', 'uuid': 'A2Gl', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: statistiques, loi de Poisson, estimateurs, maximum de vraisemblance
#   Classification basée sur le thème: Statistique / Estimation
#   Classification réussie: Statistique / Estimation
#   ✓ Informations insérées dans ../src/latex/amscc/A2Gl.tex
# [115/458] Traitement du fichier: ../src/latex/amscc/wBKf.tex
# Classification du fichier: ../src/latex/amscc/wBKf.tex
#   Métadonnées trouvées: {'titre': 'Simplification de nombres complexes', 'theme': 'complexes', 'uuid': 'wBKf', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: complexes
#   Classification basée sur le thème: Nombres complexes / Autre
#   Classification réussie: Nombres complexes / Autre
#   ✓ Informations insérées dans ../src/latex/amscc/wBKf.tex
# [116/458] Traitement du fichier: ../src/latex/amscc/rsjs.tex
# Classification du fichier: ../src/latex/amscc/rsjs.tex
#   Métadonnées trouvées: {'titre': 'Optimisation quadratique, moindres carrés', 'theme': 'optimisation', 'uuid': 'rsjs', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: optimisation
#   Classification basée sur le thème: Optimisation / Autre
#   Classification réussie: Optimisation / Autre
#   ✓ Informations insérées dans ../src/latex/amscc/rsjs.tex
# [117/458] Traitement du fichier: ../src/latex/amscc/6TSn.tex
# Classification du fichier: ../src/latex/amscc/6TSn.tex
#   Métadonnées trouvées: {'titre': 'Problème de clés', 'theme': 'dénombrement', 'uuid': '6TSn', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: dénombrement
#   Classification basée sur le thème: Dénombrement / Autre
#   Classification réussie: Dénombrement / Autre
#   ✓ Informations insérées dans ../src/latex/amscc/6TSn.tex
# [118/458] Traitement du fichier: ../src/latex/amscc/lX53.tex
# Classification du fichier: ../src/latex/amscc/lX53.tex
#   Métadonnées trouvées: {'titre': 'Loi géométrique et estimation par maximum de vraisemblance', 'theme': 'loi géométrique, maximum de vraisemblance', 'uuid': 'lX53', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: loi géométrique, maximum de vraisemblance
#   Classification basée sur le thème: Probabilité discrète / Lois de distributions
#   Classification réussie: Probabilité discrète / Lois de distributions
#   ✓ Informations insérées dans ../src/latex/amscc/lX53.tex
# [119/458] Traitement du fichier: ../src/latex/amscc/3kdw.tex
# Classification du fichier: ../src/latex/amscc/3kdw.tex
#   Métadonnées trouvées: {'titre': "Lois statistiques et étude d'estimateurs", 'theme': 'statistiques, estimateurs', 'uuid': '3kdw', 'auteur': 'Maxime NGUYEN', 'organisation': 'AMSCC'}
#   Thème trouvé: statistiques, estimateurs
#   Classification basée sur le thème: Statistique / Estimation
#   Classification réussie: Statistique / Estimation
#   ✓ Informations insérées dans ../src/latex/amscc/3kdw.tex
# [120/458] Traitement du fichier: ../src/latex/amscc/lH75.tex
# Classification du fichier: ../src/latex/amscc/lH75.tex
#   Métadonnées trouvées: {'titre': "Extremum d'un polynôme", 'theme': 'calcul différentiel, optimisation', 'uuid': 'lH75', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: calcul différentiel, optimisation
#   Classification basée sur le thème: Dérivabilité des fonctions réelles / Applications
#   Classification réussie: Dérivabilité des fonctions réelles / Applications
#   ✓ Informations insérées dans ../src/latex/amscc/lH75.tex
# [121/458] Traitement du fichier: ../src/latex/amscc/zhwJ.tex
# Classification du fichier: ../src/latex/amscc/zhwJ.tex
#   Métadonnées trouvées: {'titre': "Etude d'extrema", 'theme': 'calcul différentiel, optimisation', 'uuid': 'zhwJ', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: calcul différentiel, optimisation
#   Classification basée sur le thème: Fonction de plusieurs variables / Extremums locaux
#   Classification réussie: Fonction de plusieurs variables / Extremums locaux
#   ✓ Informations insérées dans ../src/latex/amscc/zhwJ.tex
# [122/458] Traitement du fichier: ../src/latex/amscc/hLkm.tex
# Classification du fichier: ../src/latex/amscc/hLkm.tex
#   Métadonnées trouvées: {'titre': "Etude d'un schéma numérique", 'theme': 'analyse numérique', 'uuid': 'hLkm', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: analyse numérique
#   Classification basée sur le thème: Analyse numérique / Autre
#   Classification réussie: Analyse numérique / Autre
#   ✓ Informations insérées dans ../src/latex/amscc/hLkm.tex
# [123/458] Traitement du fichier: ../src/latex/amscc/tLxt.tex
# Classification du fichier: ../src/latex/amscc/tLxt.tex
#   Métadonnées trouvées: {'titre': 'Modélisation et matrices', 'theme': 'calcul matriciel', 'uuid': 'tLxt', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: calcul matriciel
#   Classification basée sur le thème: Matrice / Propriétés élémentaires, généralités
#   Classification réussie: Matrice / Propriétés élémentaires, généralités
#   ✓ Informations insérées dans ../src/latex/amscc/tLxt.tex
# [124/458] Traitement du fichier: ../src/latex/amscc/j4xc.tex
# Classification du fichier: ../src/latex/amscc/j4xc.tex
#   Métadonnées trouvées: {'titre': "Etude d'une loi de probabilité", 'theme': 'variables aléatoires à densité', 'uuid': 'j4xc', 'auteur': 'Maxime NGUYEN', 'organisation': 'AMSCC'}
#   Thème trouvé: variables aléatoires à densité
#   Classification basée sur le thème: Probabilité continue / Densité de probabilité
#   Classification réussie: Probabilité continue / Densité de probabilité
#   ✓ Informations insérées dans ../src/latex/amscc/j4xc.tex
# [125/458] Traitement du fichier: ../src/latex/amscc/GmNP.tex
# Classification du fichier: ../src/latex/amscc/GmNP.tex
#   Métadonnées trouvées: {'titre': 'Convergence en loi', 'theme': 'fonction caractéristique, convergence en loi', 'uuid': 'GmNP', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: fonction caractéristique, convergence en loi
#   Classification basée sur le thème: Probabilité continue / Convergence en loi
#   Classification réussie: Probabilité continue / Convergence en loi
#   ✓ Informations insérées dans ../src/latex/amscc/GmNP.tex
# [126/458] Traitement du fichier: ../src/latex/amscc/nxfH.tex
# Classification du fichier: ../src/latex/amscc/nxfH.tex
#   Métadonnées trouvées: {'titre': "Convergence d'une suite de variables aléatoires", 'theme': 'variables aléatoires à densité, convergence en probabilité, convergence en loi, théorème central limite', 'uuid': 'nxfH', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: variables aléatoires à densité, convergence en probabilité, convergence en loi, théorème central limite
#   Classification basée sur le thème: Probabilité continue / Convergence en loi
#   Classification réussie: Probabilité continue / Convergence en loi
#   ✓ Informations insérées dans ../src/latex/amscc/nxfH.tex
# [127/458] Traitement du fichier: ../src/latex/amscc/urin.tex
# Classification du fichier: ../src/latex/amscc/urin.tex
#   Métadonnées trouvées: {'titre': " Calcul d'une somme de série entière", 'uuid': 'urin', 'auteur': ' ', 'organisation': ' AMSCC '}
#   Tentative de classification basée sur le contenu de l'exercice...
#   Classification basée sur le contenu: Série entière / Calcul de la somme d'une série entière
# ...
#   Classification basée sur le thème: Matrice / Propriétés élémentaires, généralités
#   Classification réussie: Matrice / Propriétés élémentaires, généralités
#   ✓ Informations insérées dans ../src/latex/amscc/t0mY.tex
# [431/458] Traitement du fichier: ../src/latex/amscc/vUFN.tex
# Classification du fichier: ../src/latex/amscc/vUFN.tex
#   Métadonnées trouvées: {'titre': "Loi d'un couple", 'theme': 'variables aléatoires discrètes, loi conjointe', 'uuid': 'vUFN', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: variables aléatoires discrètes, loi conjointe
#   Classification basée sur le thème: Probabilité discrète / Variable aléatoire discrète
#   Classification réussie: Probabilité discrète / Variable aléatoire discrète
#   ✓ Informations insérées dans ../src/latex/amscc/vUFN.tex
# [432/458] Traitement du fichier: ../src/latex/amscc/EZfx.tex
# Classification du fichier: ../src/latex/amscc/EZfx.tex
#   Métadonnées trouvées: {'titre': 'Lois pour les statistiques', 'theme': 'loi normale, loi du chi2, loi de Student', 'uuid': 'EZfx', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: loi normale, loi du chi2, loi de Student
#   Classification basée sur le thème: Statistique / Tests d'hypothèses, intervalle de confiance
#   Classification réussie: Statistique / Tests d'hypothèses, intervalle de confiance
#   ✓ Informations insérées dans ../src/latex/amscc/EZfx.tex
# [433/458] Traitement du fichier: ../src/latex/amscc/FH8I.tex
# Classification du fichier: ../src/latex/amscc/FH8I.tex
#   Métadonnées trouvées: {'titre': 'Convergence de la descente de gradient', 'theme': 'optimisation', 'uuid': 'FH8I', 'auteur': 'Erwan HILLION', 'organisation': 'AMSCC'}
#   Thème trouvé: optimisation
#   Classification basée sur le thème: Résolution de systèmes linéaires : méthode itérative / Résolution de systèmes linéaires : méthode de gradient
#   Classification réussie: Résolution de systèmes linéaires : méthode itérative / Résolution de systèmes linéaires : méthode de gradient
#   ✓ Informations insérées dans ../src/latex/amscc/FH8I.tex
# [434/458] Traitement du fichier: ../src/latex/amscc/0e0x.tex
# Classification du fichier: ../src/latex/amscc/0e0x.tex
#   Métadonnées trouvées: {'titre': 'Estimateurs et intervalles de confiance', 'theme': 'statistiques', 'uuid': '0e0x', 'auteur': 'Maxime NGUYEN', 'organisation': 'AMSCC'}
#   Thème trouvé: statistiques
#   Classification basée sur le thème: Statistique / Estimation
#   Classification réussie: Statistique / Estimation
#   ✓ Informations insérées dans ../src/latex/amscc/0e0x.tex
# [435/458] Traitement du fichier: ../src/latex/amscc/9iIv.tex
# Classification du fichier: ../src/latex/amscc/9iIv.tex
#   Métadonnées trouvées: {'titre': ' Lois pour les statistiques ', 'theme': 'statistiques, estimateurs, loi du chi2', 'uuid': '9iIv', 'auteur': 'Maxime NGUYEN', 'organisation': 'AMSCC'}
#   Thème trouvé: statistiques, estimateurs, loi du chi2
#   Classification basée sur le thème: Statistique / Tests d'hypothèses, intervalle de confiance
#   Classification réussie: Statistique / Tests d'hypothèses, intervalle de confiance
#   ✓ Informations insérées dans ../src/latex/amscc/9iIv.tex
# [436/458] Traitement du fichier: ../src/latex/amscc/iQqS.tex
# Classification du fichier: ../src/latex/amscc/iQqS.tex
#   Métadonnées trouvées: {'titre': 'Probabilité de surcharge', 'theme': 'loi normale, théorème central limite, intervalle de confiance', 'uuid': 'iQqS', 'auteur': 'Maxime Nguyen', 'organisation': 'AMSCC'}
#   Thème trouvé: loi normale, théorème central limite, intervalle de confiance
#   Classification basée sur le thème: Probabilité continue / Loi normale
#   Classification réussie: Probabilité continue / Loi normale
#   ✓ Informations insérées dans ../src/latex/amscc/iQqS.tex
# [437/458] Traitement du fichier: ../src/latex/amscc/qAIw.tex
# Classification du fichier: ../src/latex/amscc/qAIw.tex
#   Métadonnées trouvées: {'titre': " Représentation d'une fonction réelle par un réseau de neurones", 'theme': 'réseaux de neurones', 'uuid': 'qAIw', 'auteur': ' Maxime NGUYEN ', 'organisation': ' AMSCC '}
#   Thème trouvé: réseaux de neurones
#   Classification basée sur le thème: Autre / Autre
#   Classification réussie: Autre / Autre
#   ✓ Informations insérées dans ../src/latex/amscc/qAIw.tex
# [438/458] Traitement du fichier: ../src/latex/amscc/j0O1.tex
# Classification du fichier: ../src/latex/amscc/j0O1.tex
#   Métadonnées trouvées: {'titre': " Simulation d'une loi de Pareto ", 'theme': 'variables aléatoires à densité, simulation de loi', 'uuid': 'j0O1', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: variables aléatoires à densité, simulation de loi
#   Classification basée sur le thème: Probabilité continue / Densité de probabilité
#   Classification réussie: Probabilité continue / Densité de probabilité
#   ✓ Informations insérées dans ../src/latex/amscc/j0O1.tex
# [439/458] Traitement du fichier: ../src/latex/amscc/mjqR.tex
# Classification du fichier: ../src/latex/amscc/mjqR.tex
#   Métadonnées trouvées: {'titre': "\\'Etude de séries numériques", 'theme': 'séries', 'uuid': 'mjqR', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: séries
#   Classification basée sur le thème: Série numérique / Série à termes positifs
#   Classification réussie: Série numérique / Série à termes positifs
#   ✓ Informations insérées dans ../src/latex/amscc/mjqR.tex
# [440/458] Traitement du fichier: ../src/latex/amscc/ZTjz.tex
# Classification du fichier: ../src/latex/amscc/ZTjz.tex
#   Métadonnées trouvées: {'titre': 'Développement limité', 'theme': 'analyse asymptotique', 'uuid': 'ZTjz', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: analyse asymptotique
#   Classification basée sur le thème: Développement limité / Applications
#   Classification réussie: Développement limité / Applications
#   ✓ Informations insérées dans ../src/latex/amscc/ZTjz.tex
# [441/458] Traitement du fichier: ../src/latex/amscc/Bekb.tex
# Classification du fichier: ../src/latex/amscc/Bekb.tex
#   Métadonnées trouvées: {'titre': ' Fonction réalisée par un réseau de neurones ', 'theme': 'réseaux de neurones', 'uuid': 'Bekb', 'auteur': ' Maxime NGUYEN ', 'organisation': ' AMSCC '}
#   Thème trouvé: réseaux de neurones
#   Classification basée sur le thème: Autre / Autre
#   Classification réussie: Autre / Autre
#   ✓ Informations insérées dans ../src/latex/amscc/Bekb.tex
# [442/458] Traitement du fichier: ../src/latex/amscc/HqCj.tex
# Classification du fichier: ../src/latex/amscc/HqCj.tex
#   Métadonnées trouvées: {'titre': 'Conformité de la teneur en thiomersal dans un vaccin grippal pandémique', 'theme': "tests d'hypothèses", 'uuid': 'HqCj', 'auteur': 'Maxime NGUYEN', 'organisation': 'AMSCC'}
#   Thème trouvé: tests d'hypothèses
#   Classification basée sur le thème: Statistique / Tests d'hypothèses, intervalle de confiance
#   Classification réussie: Statistique / Tests d'hypothèses, intervalle de confiance
#   ✓ Informations insérées dans ../src/latex/amscc/HqCj.tex
# [443/458] Traitement du fichier: ../src/latex/amscc/qyPc.tex
# Classification du fichier: ../src/latex/amscc/qyPc.tex
#   Métadonnées trouvées: {'titre': 'Lois de probabilité, simulation', 'theme': 'variables aléatoires à densité, simulation de loi', 'uuid': 'qyPc', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: variables aléatoires à densité, simulation de loi
#   Classification basée sur le thème: Probabilité continue / Densité de probabilité
#   Classification réussie: Probabilité continue / Densité de probabilité
#   ✓ Informations insérées dans ../src/latex/amscc/qyPc.tex
# [444/458] Traitement du fichier: ../src/latex/amscc/ad69.tex
# Classification du fichier: ../src/latex/amscc/ad69.tex
#   Métadonnées trouvées: {'titre': 'Marche aléatoire', 'theme': 'probabilités conditionnelles', 'uuid': 'ad69', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: probabilités conditionnelles
#   Classification basée sur le thème: Probabilité discrète / Probabilité conditionnelle
#   Classification réussie: Probabilité discrète / Probabilité conditionnelle
#   ✓ Informations insérées dans ../src/latex/amscc/ad69.tex
# [445/458] Traitement du fichier: ../src/latex/amscc/I4Tf.tex
# Classification du fichier: ../src/latex/amscc/I4Tf.tex
#   Métadonnées trouvées: {'titre': 'Ouverts et fermés dans $\\R$', 'theme': 'topologie', 'uuid': 'I4Tf', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: topologie
#   Classification basée sur le thème: Topologie / Ouvert, fermé, intérieur, adhérence
#   Classification réussie: Topologie / Ouvert, fermé, intérieur, adhérence
#   ✓ Informations insérées dans ../src/latex/amscc/I4Tf.tex
# [446/458] Traitement du fichier: ../src/latex/amscc/4Z0U.tex
# Classification du fichier: ../src/latex/amscc/4Z0U.tex
#   Métadonnées trouvées: {'titre': "Etude d'un jeu", 'theme': 'variables aléatoires discrètes, approximation de loi', 'uuid': '4Z0U', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: variables aléatoires discrètes, approximation de loi
#   Classification basée sur le thème: Probabilité discrète / Variable aléatoire discrète
#   Classification réussie: Probabilité discrète / Variable aléatoire discrète
#   ✓ Informations insérées dans ../src/latex/amscc/4Z0U.tex
# [447/458] Traitement du fichier: ../src/latex/amscc/Vss4.tex
# Classification du fichier: ../src/latex/amscc/Vss4.tex
#   Métadonnées trouvées: {'titre': "Contrôle de qualité sur des pièces d'un euro", 'theme': 'théorème central limite, approximation de loi', 'uuid': 'Vss4', 'auteur': ' ', 'organisation': ' AMSCC '}
#   Thème trouvé: théorème central limite, approximation de loi
#   Classification basée sur le thème: Probabilité continue / Lois des grands nombres, théorème central limite
#   Classification réussie: Probabilité continue / Lois des grands nombres, théorème central limite
#   ✓ Informations insérées dans ../src/latex/amscc/Vss4.tex
# [448/458] Traitement du fichier: ../src/latex/amscc/zhq8.tex
# Classification du fichier: ../src/latex/amscc/zhq8.tex
#   Métadonnées trouvées: {'titre': 'Construction de la loi du $\\chi^2$', 'theme': 'variables aléatoires à densité, loi du chi2', 'uuid': 'zhq8', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: variables aléatoires à densité, loi du chi2
#   Classification basée sur le thème: Probabilité continue / Densité de probabilité
#   Classification réussie: Probabilité continue / Densité de probabilité
#   ✓ Informations insérées dans ../src/latex/amscc/zhq8.tex
# [449/458] Traitement du fichier: ../src/latex/amscc/FIgO.tex
# Classification du fichier: ../src/latex/amscc/FIgO.tex
#   Métadonnées trouvées: {'titre': "Loi d'un couple", 'theme': 'loi conjointe', 'uuid': 'FIgO', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: loi conjointe
#   Classification basée sur le thème: Probabilité discrète / Loi, indépendance, loi conditionnelle
#   Classification réussie: Probabilité discrète / Loi, indépendance, loi conditionnelle
#   ✓ Informations insérées dans ../src/latex/amscc/FIgO.tex
# [450/458] Traitement du fichier: ../src/latex/amscc/xQe9.tex
# Classification du fichier: ../src/latex/amscc/xQe9.tex
#   Métadonnées trouvées: {'titre': "Etude d'une loi de probabilité", 'theme': 'variables aléatoires à densité', 'uuid': 'xQe9', 'auteur': 'Maxime Nguyen', 'organisation': 'AMSCC'}
#   Thème trouvé: variables aléatoires à densité
#   Classification basée sur le thème: Probabilité continue / Densité de probabilité
#   Classification réussie: Probabilité continue / Densité de probabilité
#   ✓ Informations insérées dans ../src/latex/amscc/xQe9.tex
# [451/458] Traitement du fichier: ../src/latex/amscc/BVLI.tex
# Classification du fichier: ../src/latex/amscc/BVLI.tex
#   Métadonnées trouvées: {'titre': 'Optimisation sans contrainte', 'theme': 'optimisation', 'uuid': 'BVLI', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: optimisation
#   Classification basée sur le thème: Fonction de plusieurs variables / Extremums locaux
#   Classification réussie: Fonction de plusieurs variables / Extremums locaux
#   ✓ Informations insérées dans ../src/latex/amscc/BVLI.tex
# [452/458] Traitement du fichier: ../src/latex/amscc/ieFw.tex
# Classification du fichier: ../src/latex/amscc/ieFw.tex
#   Métadonnées trouvées: {'titre': 'Domaine de convergence de séries sentières', 'theme': 'séries entières', 'uuid': 'ieFw', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: séries entières
#   Classification basée sur le thème: Série entière / Rayon de convergence
#   Classification réussie: Série entière / Rayon de convergence
#   ✓ Informations insérées dans ../src/latex/amscc/ieFw.tex
# [453/458] Traitement du fichier: ../src/latex/amscc/kJz6.tex
# Classification du fichier: ../src/latex/amscc/kJz6.tex
#   Métadonnées trouvées: {'titre': "Probabilité d'événements", 'theme': 'probabilités', 'uuid': 'kJz6', 'auteur': ' ', 'organisation': 'AMSCC'}
#   Thème trouvé: probabilités
#   Classification basée sur le thème: Probabilité discrète / Probabilité et dénombrement
#   Classification réussie: Probabilité discrète / Probabilité et dénombrement
#   ✓ Informations insérées dans ../src/latex/amscc/kJz6.tex
# [454/458] Traitement du fichier: ../src/latex/amscc/HXRf.tex
# Classification du fichier: ../src/latex/amscc/HXRf.tex
#   Métadonnées trouvées: {'titre': 'Simulation et classement sur tableur', 'theme': 'statistiques, tableur', 'uuid': 'HXRf', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: statistiques, tableur
#   Classification basée sur le thème: Statistique / Autre
#   Classification réussie: Statistique / Autre
#   ✓ Informations insérées dans ../src/latex/amscc/HXRf.tex
# [455/458] Traitement du fichier: ../src/latex/amscc/aOYg.tex
# Classification du fichier: ../src/latex/amscc/aOYg.tex
#   Métadonnées trouvées: {'titre': "Etude d'une matrice pentadiagonale", 'theme': 'analyse numérique', 'uuid': 'aOYg', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: analyse numérique
#   Classification basée sur le thème: Résolution de systèmes linéaires : méthode itérative / Résolution de systèmes linéaires : méthode itérative
#   Classification réussie: Résolution de systèmes linéaires : méthode itérative / Résolution de systèmes linéaires : méthode itérative
#   ✓ Informations insérées dans ../src/latex/amscc/aOYg.tex
# [456/458] Traitement du fichier: ../src/latex/amscc/Jiv8.tex
# Classification du fichier: ../src/latex/amscc/Jiv8.tex
#   Métadonnées trouvées: {'titre': 'Lois pour les statistiques', 'theme': 'loi normale, loi du chi2, loi de Student, loi de Fisher', 'uuid': 'Jiv8', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: loi normale, loi du chi2, loi de Student, loi de Fisher
#   Classification basée sur le thème: Statistique / Tests d'hypothèses, intervalle de confiance
#   Classification réussie: Statistique / Tests d'hypothèses, intervalle de confiance
#   ✓ Informations insérées dans ../src/latex/amscc/Jiv8.tex
# [457/458] Traitement du fichier: ../src/latex/amscc/b1T2.tex
# Classification du fichier: ../src/latex/amscc/b1T2.tex
#   Métadonnées trouvées: {'titre': "Etude d'une matrice tridiagonale", 'theme': 'analyse numérique', 'uuid': 'b1T2', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: analyse numérique
#   Classification basée sur le thème: Résolution de systèmes linéaires : méthode itérative / Résolution de systèmes linéaires : méthode itérative
#   Classification réussie: Résolution de systèmes linéaires : méthode itérative / Résolution de systèmes linéaires : méthode itérative
#   ✓ Informations insérées dans ../src/latex/amscc/b1T2.tex
# [458/458] Traitement du fichier: ../src/latex/amscc/CuTJ.tex
# Classification du fichier: ../src/latex/amscc/CuTJ.tex
#   Métadonnées trouvées: {'titre': 'Calcul de reste de division euclidienne', 'theme': 'polynômes', 'uuid': 'CuTJ', 'auteur': '', 'organisation': 'AMSCC'}
#   Thème trouvé: polynômes
#   Classification basée sur le thème: Polynôme, fraction rationnelle / Division euclidienne
#   Classification réussie: Polynôme, fraction rationnelle / Division euclidienne
#   ✓ Informations insérées dans ../src/latex/amscc/CuTJ.tex
#
# === RÉSUMÉ DU TRAITEMENT ===
# Total des fichiers traités: 458
# Fichiers déjà classifiés: 49
# Fichiers nouvellement classifiés: 409
# Échecs de classification: 0
# Taux de réussite: 100.00% des fichiers non classifiés
